# %%
import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt
import astropy.units as u
from astropy.io import fits
from astropy.stats import sigma_clipped_stats, sigma_clip
from astropy.table import Table
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS
from astropy.visualization import ZScaleInterval
from astroquery.vizier import Vizier
import subprocess
import os

# %%
def test_dependency(dep, alternate_name=None):
    """
    Test external dependency by trying to run it as a subprocess
    """
    try:
        subprocess.check_output(dep, stderr=subprocess.PIPE, shell=True)
        print("%s is installed properly as %s. OK" % (dep, dep))
        return 1
    except subprocess.CalledProcessError:
        try:
            subprocess.check_output(alternate_name, stderr=subprocess.PIPE, shell=True)
            print("%s is installed properly as %s. OK" % (dep, alternate_name))
            return 1
        except subprocess.CalledProcessError:
            print("===%s/%s IS NOT YET INSTALLED PROPERLY===" % (dep, alternate_name))
            return 0
    
dependencies = [('source-extractor', 'sex'), ('psfex', 'PSFEx')]
i = 0
for dep_name1, dep_name2 in dependencies:
    i += test_dependency(dep_name1, dep_name2)
print("%i out of %i external dependencies installed properly.\n" % (i, len(dependencies)))
if i != len(dependencies):
    print("Please correctly install these programs before continuing by following the instructions in README.md.")
else:
    print("You are ready to continue.")
# Out:
# source-extractor is installed properly as sex. OK
# psfex is installed properly as psfex. OK
# 2 out of 2 external dependencies installed properly.
#
# You are ready to continue.

# %%
os.chdir('/Users/jigyasachouhan/Documents/Krittika/KSP/Task 2/files_TASK_2')
imageName = '20230528153428-317-RA.wcs.proc.fits'

with fits.open(imageName) as HDUList:
    header = HDUList[0].header
    image = HDUList[0].data

zscale = ZScaleInterval().get_limits(image)

plt.figure(figsize=(10,10))
plt.imshow(image, cmap='gray', origin='lower', vmin=zscale[0], vmax=zscale[1])
plt.colorbar()
plt.show()

# %%
w = WCS(header)
(raImage, decImage) = w.all_pix2world(image.shape[0]/2, image.shape[1]/2, 1)
boxsize = 30 # arcminutes
maxmag = 18

catNum = 'II/349'
print(f'\nQuerying Vizier {catNum} around RA {raImage:.4f}, Dec {decImage:.4f} with a radius of {boxsize} arcmin')

try:
    # You can set the filters for the individual columns (magnitude range, number of detections) inside the Vizier query
    v = Vizier(columns=['*'], column_filters={"gmag":f"<{maxmag}", "Nd":">6", "e_gmag":f"<{1.086/3}"}, row_limit=-1)
    Q = v.query_region(SkyCoord(ra=raImage, dec=decImage, unit=(u.deg, u.deg)), radius=str(boxsize)+'m', catalog=catNum, cache=False)
    print(Q[0])
except:
    print('I cannnot reach the Vizier database. Is the internet working?')
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60092.648939 from DATE-OBS'. [astropy.wcs.wcs]
# Querying Vizier II/349 around RA 211.1048, Dec 54.3093 with a radius of 30 arcmin
#    RAJ2000       DEJ2000          objID        ...  yKmag  e_yKmag yFlags
#      deg           deg                         ...   mag     mag
# ------------- ------------- ------------------ ... ------- ------- ------
# 210.729459870  53.862978240 172632107294506278 ... 15.1832  0.0043 115000
# 210.663724090  53.919290610 172702106637313866 ... 16.4559  0.0164 115000
# 210.663539540  53.892741500 172672106635471999 ... 16.3082  0.0166 115000
# 210.604486980  53.926405740 172712106044792397 ... 16.4376  0.0142 115000
# 210.625757450  53.949266840 172732106257949830 ... 13.8435  0.0035 115000
# 210.559704780  53.937696580 172722105596905934 ... 15.5672  0.0071 115000
# 210.439170920  54.003287860 172802104391914650 ... 14.9887  0.0043 115000
# 210.447712130  54.046944570 172852104477077040 ... 14.0260  0.0031 115000
# 210.394009680  54.069378840 172882103939893987 ... 15.2874  0.0041 115000
#           ...           ...                ... ...     ...     ...    ...
# 211.391153460  54.714378780 173652113911607878 ... 15.1235  0.0104 115000
# 211.389644660  54.709108870 173652113897101556 ... 14.3704  0.0030 115000
# 211.383188040  54.721429910 173662113832166340 ... 14.7420  0.0198 115000
# 211.447903520  54.683426060 173622114479190746 ... 16.5702  0.0106 115000
# 211.397292700  54.731710700 173672113972788684 ... 16.2727  0.0165 115000
# 211.450513470  54.748214270 173692114504318428 ... 14.5338  0.0032 115000
# 211.418571590  54.758291300 173712114185810617 ... 14.8753  0.0026 115000
# 211.325299540  54.736859470 173682113252044964 ... 12.9410  0.0051 115000
# 211.341417080  54.752394860 173702113414513525 ... 14.2975  0.0106 115000
# 211.312292400  54.789897370 173742113123078539 ... 14.0685  0.0011 115000
# Length = 631 rows

# %%
Q[0].meta['desc'] = Q[0].meta.pop('description')
Q[0].write('/Users/jigyasachouhan/Documents/Krittika/KSP/Task 2/files_TASK_2/ps1Catalog.fits', format='fits', overwrite=True)

# %%
ps1_imCoords = w.all_world2pix(Q[0]['RAJ2000'], Q[0]['DEJ2000'], 1)
good_cat_stars = Q[0][np.where((ps1_imCoords[0] > 500) & (ps1_imCoords[0] < 3500) & (ps1_imCoords[1] > 500) & (ps1_imCoords[1] < 3500))]
ps1_imCoords = w.all_world2pix(good_cat_stars['RAJ2000'],good_cat_stars['DEJ2000'], 1)

fig = plt.figure(figsize=(10,10))
ax = fig.gca()
plt.imshow(image, cmap='gray', vmin=zscale[0], vmax=zscale[1])
circles = [plt.Circle((ps1_imCoords[0][i], ps1_imCoords[1][i]), radius = 10, edgecolor='C1', facecolor='None') for i in range(len(ps1_imCoords[0]))]
for c in circles:
    ax.add_artist(c)
    
plt.show()

# %%
configFile = 'photomCat.sex'
catalogName = imageName + '.cat'
paramName = 'photomCat.param'
try:
    command = f'sex -c {configFile} {imageName} -CATALOG_NAME {catalogName} -PARAMETERS_NAME {paramName}'
    print(f'Executing command: {command}')
    rval = subprocess.run(command.split(), check=True)
except subprocess.CalledProcessError as err:
    print(f'Could not run sextractor with exit error {err}')
# Out:
# Executing command: sex -c photomCat.sex 20230528153428-317-RA.wcs.proc.fits -CATALOG_NAME 20230528153428-317-RA.wcs.proc.fits.cat -PARAMETERS_NAME photomCat.param
# >
# ----- SExtractor 2.28.0 started on 2024-07-01 at 12:06:25 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing catalog
# > Looking for 20230528153428-317-RA.wcs.proc.fits
# ----- Measuring from: 20230528153428-317-RA.wcs.proc.fits
#       "SN2023ixf" / no ext. header / 4096x4108 / 64 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line: 1024
# > Setting up background map at line: 2048
# > Setting up background map at line: 3072
# > Setting up background map at line: 4096
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 148.21     RMS: 14.3777    / Threshold: 143.777
# > Scanning image
# > Line:   25  Objects:        1 detected /        0 sextracted
# > Line:   50  Objects:        1 detected /        0 sextracted
# > Line:   75  Objects:        2 detected /        0 sextracted
# > Line:  100  Objects:        2 detected /        0 sextracted
# > Line:  125  Objects:        2 detected /        0 sextracted
# > Line:  150  Objects:        4 detected /        0 sextracted
# > Line:  175  Objects:        5 detected /        0 sextracted
# > Line:  200  Objects:        5 detected /        0 sextracted
# > Line:  225  Objects:        5 detected /        0 sextracted
# > Line:  250  Objects:        7 detected /        0 sextracted
# > Line:  275  Objects:        7 detected /        0 sextracted
# > Line:  300  Objects:        7 detected /        0 sextracted
# > Line:  325  Objects:        8 detected /        0 sextracted
# > Line:  350  Objects:        8 detected /        0 sextracted
# > Line:  375  Objects:       10 detected /        0 sextracted
# > Line:  400  Objects:       10 detected /        0 sextracted
# > Line:  425  Objects:       12 detected /        0 sextracted
# > Line:  450  Objects:       13 detected /        0 sextracted
# > Line:  475  Objects:       13 detected /        0 sextracted
# > Line:  500  Objects:       14 detected /        0 sextracted
# > Line:  525  Objects:       17 detected /        0 sextracted
# > Line:  550  Objects:       19 detected /        0 sextracted
# > Line:  575  Objects:       19 detected /        0 sextracted
# > Line:  600  Objects:       19 detected /        0 sextracted
# > Line:  625  Objects:       19 detected /        0 sextracted
# > Line:  650  Objects:       20 detected /        0 sextracted
# > Line:  675  Objects:       22 detected /        0 sextracted
# > Line:  700  Objects:       24 detected /        0 sextracted
# > Line:  725  Objects:       25 detected /        0 sextracted
# > Line:  750  Objects:       25 detected /        0 sextracted
# > Line:  775  Objects:       27 detected /        0 sextracted
# > Line:  800  Objects:       30 detected /        0 sextracted
# > Line:  825  Objects:       31 detected /        0 sextracted
# > Line:  850  Objects:       32 detected /        0 sextracted
# > Line:  875  Objects:       32 detected /        0 sextracted
# > Line:  900  Objects:       32 detected /        0 sextracted
# > Line:  925  Objects:       36 detected /        0 sextracted
# > Line:  950  Objects:       37 detected /        0 sextracted
# > Line:  975  Objects:       40 detected /        0 sextracted
# > Line: 1000  Objects:       40 detected /        0 sextracted
# > Line: 1023  Objects:       40 detected /        0 sextracted
# > Line: 1025  Objects:       40 detected /        1 sextracted
# > Line: 1050  Objects:       41 detected /        1 sextracted
# > Line: 1075  Objects:       42 detected /        1 sextracted
# > Line: 1100  Objects:       44 detected /        2 sextracted
# > Line: 1125  Objects:       46 detected /        2 sextracted
# > Line: 1150  Objects:       46 detected /        3 sextracted
# > Line: 1175  Objects:       46 detected /        5 sextracted
# > Line: 1200  Objects:       47 detected /        5 sextracted
# > Line: 1225  Objects:       47 detected /        6 sextracted
# > Line: 1250  Objects:       48 detected /        6 sextracted
# > Line: 1275  Objects:       49 detected /        7 sextracted
# > Line: 1300  Objects:       51 detected /        7 sextracted
# > Line: 1325  Objects:       51 detected /        8 sextracted
# > Line: 1350  Objects:       51 detected /        8 sextracted
# > Line: 1375  Objects:       52 detected /       10 sextracted
# > Line: 1400  Objects:       53 detected /       10 sextracted
# > Line: 1425  Objects:       56 detected /       12 sextracted
# > Line: 1450  Objects:       58 detected /       13 sextracted
# > Line: 1475  Objects:       59 detected /       13 sextracted
# > Line: 1500  Objects:       61 detected /       14 sextracted
# > Line: 1525  Objects:       64 detected /       17 sextracted
# > Line: 1550  Objects:       64 detected /       19 sextracted
# > Line: 1575  Objects:       65 detected /       19 sextracted
# > Line: 1600  Objects:       65 detected /       19 sextracted
# > Line: 1625  Objects:       67 detected /       19 sextracted
# > Line: 1650  Objects:       68 detected /       20 sextracted
# > Line: 1675  Objects:       69 detected /       22 sextracted
# > Line: 1700  Objects:       69 detected /       23 sextracted
# > Line: 1725  Objects:       72 detected /       25 sextracted
# > Line: 1750  Objects:       72 detected /       25 sextracted
# > Line: 1775  Objects:       73 detected /       27 sextracted
# > Line: 1800  Objects:       73 detected /       29 sextracted
# > Line: 1825  Objects:       73 detected /       31 sextracted
# > Line: 1850  Objects:       73 detected /       32 sextracted
# > Line: 1875  Objects:       74 detected /       32 sextracted
# > Line: 1900  Objects:       76 detected /       33 sextracted
# > Line: 1925  Objects:       76 detected /       35 sextracted
# > Line: 1950  Objects:       79 detected /       38 sextracted
# > Line: 1975  Objects:       81 detected /       40 sextracted
# > Line: 2000  Objects:       82 detected /       40 sextracted
# > Line: 2025  Objects:       82 detected /       40 sextracted
# > Line: 2050  Objects:       82 detected /       40 sextracted
# > Line: 2075  Objects:       83 detected /       42 sextracted
# > Line: 2100  Objects:       85 detected /       44 sextracted
# > Line: 2125  Objects:       87 detected /       46 sextracted
# > Line: 2150  Objects:       88 detected /       46 sextracted
# > Line: 2175  Objects:       88 detected /       46 sextracted
# > Line: 2200  Objects:       89 detected /       47 sextracted
# > Line: 2225  Objects:       90 detected /       47 sextracted
# > Line: 2250  Objects:       93 detected /       47 sextracted
# > Line: 2275  Objects:       94 detected /       49 sextracted
# > Line: 2300  Objects:       96 detected /       51 sextracted
# > Line: 2325  Objects:       97 detected /       51 sextracted
# > Line: 2350  Objects:       98 detected /       51 sextracted
# > Line: 2375  Objects:      101 detected /       52 sextracted
# > Line: 2400  Objects:      102 detected /       53 sextracted
# > Line: 2425  Objects:      103 detected /       56 sextracted
# > Line: 2450  Objects:      103 detected /       59 sextracted
# > Line: 2475  Objects:      106 detected /       59 sextracted
# > Line: 2500  Objects:      107 detected /       61 sextracted
# > Line: 2525  Objects:      107 detected /       63 sextracted
# > Line: 2550  Objects:      109 detected /       64 sextracted
# > Line: 2575  Objects:      109 detected /       65 sextracted
# > Line: 2600  Objects:      111 detected /       65 sextracted
# > Line: 2625  Objects:      114 detected /       67 sextracted
# > Line: 2650  Objects:      115 detected /       68 sextracted
# > Line: 2675  Objects:      115 detected /       69 sextracted
# > Line: 2700  Objects:      118 detected /       70 sextracted
# > Line: 2725  Objects:      119 detected /       72 sextracted
# > Line: 2750  Objects:      121 detected /       72 sextracted
# > Line: 2775  Objects:      124 detected /       73 sextracted
# > Line: 2800  Objects:      125 detected /       73 sextracted
# > Line: 2825  Objects:      129 detected /       73 sextracted
# > Line: 2850  Objects:      131 detected /       73 sextracted
# > Line: 2875  Objects:      134 detected /       74 sextracted
# > Line: 2900  Objects:      135 detected /       76 sextracted
# > Line: 2925  Objects:      136 detected /       76 sextracted
# > Line: 2950  Objects:      138 detected /       79 sextracted
# > Line: 2975  Objects:      139 detected /       81 sextracted
# > Line: 3000  Objects:      141 detected /       82 sextracted
# > Line: 3025  Objects:      142 detected /       82 sextracted
# > Line: 3050  Objects:      142 detected /       82 sextracted
# > Line: 3075  Objects:      143 detected /       84 sextracted
# > Line: 3100  Objects:      145 detected /       85 sextracted
# > Line: 3125  Objects:      146 detected /       88 sextracted
# > Line: 3150  Objects:      147 detected /       88 sextracted
# > Line: 3175  Objects:      148 detected /       89 sextracted
# > Line: 3200  Objects:      149 detected /       89 sextracted
# > Line: 3225  Objects:      151 detected /       90 sextracted
# > Line: 3250  Objects:      153 detected /       93 sextracted
# > Line: 3275  Objects:      154 detected /       93 sextracted
# > Line: 3300  Objects:      156 detected /       96 sextracted
# > Line: 3325  Objects:      160 detected /       98 sextracted
# > Line: 3350  Objects:      162 detected /       98 sextracted
# > Line: 3375  Objects:      162 detected /       99 sextracted
# > Line: 3400  Objects:      162 detected /      102 sextracted
# > Line: 3425  Objects:      163 detected /      103 sextracted
# > Line: 3450  Objects:      164 detected /      104 sextracted
# > Line: 3475  Objects:      165 detected /      106 sextracted
# > Line: 3500  Objects:      165 detected /      107 sextracted
# > Line: 3525  Objects:      166 detected /      107 sextracted
# > Line: 3550  Objects:      166 detected /      108 sextracted
# > Line: 3575  Objects:      167 detected /      109 sextracted
# > Line: 3600  Objects:      169 detected /      110 sextracted
# > Line: 3625  Objects:      171 detected /      114 sextracted
# > Line: 3650  Objects:      171 detected /      115 sextracted
# > Line: 3675  Objects:      173 detected /      116 sextracted
# > Line: 3700  Objects:      175 detected /      117 sextracted
# > Line: 3725  Objects:      175 detected /      119 sextracted
# > Line: 3750  Objects:      175 detected /      121 sextracted
# > Line: 3775  Objects:      175 detected /      123 sextracted
# > Line: 3800  Objects:      175 detected /      124 sextracted
# > Line: 3825  Objects:      177 detected /      129 sextracted
# > Line: 3850  Objects:      178 detected /      129 sextracted
# > Line: 3875  Objects:      178 detected /      129 sextracted
# > Line: 3900  Objects:      178 detected /      129 sextracted
# > Line: 3925  Objects:      179 detected /      129 sextracted
# > Line: 3950  Objects:      179 detected /      129 sextracted
# > Line: 3975  Objects:      180 detected /      129 sextracted
# > Line: 4000  Objects:      180 detected /      129 sextracted
# > Line: 4025  Objects:      181 detected /      129 sextracted
# > Line: 4050  Objects:      182 detected /      129 sextracted
# > Line: 4075  Objects:      183 detected /      129 sextracted
# > Line: 4100  Objects:      183 detected /      129 sextracted
#       Objects: detected 183      / sextracted 183
#
# > Closing files
# >
# > All done (in 0.5 s: 7538.5 lines/s , 335.8 detections/s)

# %%
with fits.open(catalogName) as HDU:
    print(HDU.info())
    sourceTable = Table(HDU[2].data)

print(sourceTable.colnames)
print(sourceTable)

cleanSources = sourceTable[(sourceTable['FLAGS']==0) & (sourceTable['FWHM_WORLD'] < 2) & (sourceTable['XWIN_IMAGE']<3500) & (sourceTable['XWIN_IMAGE']>500) & (sourceTable['YWIN_IMAGE']<3500) & (sourceTable['YWIN_IMAGE']>500)]
# Out:
# Filename: 20230528153428-317-RA.wcs.proc.fits.cat
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  LDAC_IMHEAD    1 BinTableHDU     12   1R x 1C   [19040A]
#   2  LDAC_OBJECTS    1 BinTableHDU    106   183R x 25C   [729E, 1E, 1E, 1D, 1D, 1E, 1E, 1D, 1D, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1I, 1E, 1E, 10E, 10E, 10E, 10E]
# None
# ['VIGNET', 'X_IMAGE', 'Y_IMAGE', 'XWIN_IMAGE', 'YWIN_IMAGE', 'ERRAWIN_IMAGE', 'ERRBWIN_IMAGE', 'ALPHAWIN_J2000', 'DELTAWIN_J2000', 'FLUX_RADIUS', 'FWHM_WORLD', 'FLUX_AUTO', 'FLUXERR_AUTO', 'SNR_WIN', 'ELONGATION', 'FLUX_MAX', 'MAG_AUTO', 'MAGERR_AUTO', 'FLAGS', 'BACKGROUND', 'CLASS_STAR', 'FLUX_APER', 'FLUXERR_APER', 'MAG_APER', 'MAGERR_APER']
#          VIGNET           X_IMAGE  ...          MAGERR_APER
# ------------------------ --------- ... -----------------------------
#  2.1342468 .. -0.8135681 2417.4868 ... 0.0004008853 .. 0.00040389667
# -20.300552 .. -0.6188965  2845.188 ...    0.018492002 .. 0.027472513
#   7.0771484 .. 21.869095 2503.1082 ...    0.021898435 .. 0.034604285
#    7.557373 .. -5.702667 2417.4932 ...  0.00041527883 .. 0.000418315
#     8.56395 .. 10.064987 2279.7175 ...    0.025658024 .. 0.037735246
# -0.36180115 .. 15.145096 838.68555 ...   0.0064723915 .. 0.009195597
#  1.2522888 .. -14.694656   930.012 ...    0.027831785 .. 0.086999305
#    3.055191 .. 13.893936 1233.9169 ...     0.02581779 .. 0.089699455
# -1.2296143 .. 0.44458008  3463.827 ...       0.0162377 .. 0.03059128
#  31.847015 .. -23.388725 2133.0015 ...    0.006671788 .. 0.021494012
#                      ...       ... ...                           ...
# -11.566895 .. -17.165268  589.1169 ...   0.0054122414 .. 0.009243484
#  -0.8890686 .. -3.554779 2224.3367 ...     0.01389263 .. 0.023842275
#      17.98555 .. 5.16951 3598.2766 ...    0.019651623 .. 0.039722975
#  -19.86856 .. 15.1883545 1979.9911 ...      0.03640669 .. 0.11137706
#  -3.6453857 .. 13.721619 3054.0044 ...    0.041082032 .. 0.115287766
# -14.214478 .. 0.80244446  3658.984 ...   0.002068365 .. 0.0038731454
# -44.508972 .. -28.928505   328.341 ...     0.010185668 .. 0.03278711
#  14.655151 .. -6.4913635 2778.0996 ...   0.003776837 .. 0.0069622216
# -2.7428284 .. -3.5803375 3483.9922 ...     0.039453987 .. 0.10932504
#  10.160629 .. -3.1033783  3585.002 ...    0.032994807 .. 0.100097865
# Length = 183 rows

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
plt.imshow(image, cmap='gray', vmin=zscale[0], vmax=zscale[1])
circles = [plt.Circle((source['XWIN_IMAGE'], source['YWIN_IMAGE']), radius = 10, edgecolor='C1', facecolor='None') for source in cleanSources]
for c in circles:
    ax.add_artist(c)
plt.show()

# %%
psfConfigFile = 'psfex_conf.psfex'

try:
    command = f'psfex -c {psfConfigFile} {catalogName}'
    print(f'Executing command: {command}')
    rval = subprocess.run(command.split(), check=True)
except subprocess.CalledProcessError as err:
    print(f'Could not run psfex with exit error {err}')
# Out:
# Executing command: psfex -c psfex_conf.psfex 20230528153428-317-RA.wcs.proc.fits.cat
# > WARNING: This executable has been compiled using a version of the ATLAS library without support for multithreading. Performance will be degraded.

# %%
psfModelHDU = fits.open('moffat_' + imageName + '.fits')[0]
psfModelData = psfModelHDU.data
mean, median, std = sigma_clipped_stats(psfModelData)

plt.figure(figsize=(6,6))
plt.imshow(psfModelData, vmin=0, vmax=median+20*std, origin='lower')
plt.show()

# %%
psfName = imageName + '.psf'
psfcatalogName = imageName+'.psf.cat'
psfparamName = 'photomPSF.param' # This is a new set of parameters to be obtained from SExtractor, including PSF-fit magnitudes
try:
    # We are supplying SExtactor with the PSF model with the PSF_NAME option
    command = f'sex -c {configFile} {imageName} -CATALOG_NAME {psfcatalogName} -PSF_NAME {psfName} -PARAMETERS_NAME {psfparamName}'
    print(f"Executing command: {command}")
    rval = subprocess.run(command.split(), check=True)
except subprocess.CalledProcessError as err:
    print(f'Could not run sextractor with exit error {err}')
# Out:
# Executing command: sex -c photomCat.sex 20230528153428-317-RA.wcs.proc.fits -CATALOG_NAME 20230528153428-317-RA.wcs.proc.fits.psf.cat -PSF_NAME 20230528153428-317-RA.wcs.proc.fits.psf -PARAMETERS_NAME photomPSF.param
# >
# ----- SExtractor 2.28.0 started on 2024-07-01 at 12:06:27 with 1 thread
#
# > Setting catalog parameters
# > Reading PSF information
# > Preparing profile models
# Fitting model: point source
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing catalog
# > Looking for 20230528153428-317-RA.wcs.proc.fits
# ----- Measuring from: 20230528153428-317-RA.wcs.proc.fits
#       "SN2023ixf" / no ext. header / 4096x4108 / 64 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line: 1024
# > Setting up background map at line: 2048
# > Setting up background map at line: 3072
# > Setting up background map at line: 4096
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 148.21     RMS: 14.3777    / Threshold: 143.777
# > Scanning image
# > Line:    1  Objects:        0 detected /        0 sextracted
# > Line:    2  Objects:        0 detected /        0 sextracted
# > Line:    3  Objects:        0 detected /        0 sextracted
# > Line:    4  Objects:        0 detected /        0 sextracted
# > Line:    5  Objects:        0 detected /        0 sextracted
# > Line:    6  Objects:        0 detected /        0 sextracted
# > Line:    7  Objects:        0 detected /        0 sextracted
# > Line:    8  Objects:        0 detected /        0 sextracted
# > Line:    9  Objects:        0 detected /        0 sextracted
# > Line:   10  Objects:        0 detected /        0 sextracted
# > Line:   11  Objects:        0 detected /        0 sextracted
# > Line:   12  Objects:        0 detected /        0 sextracted
# > Line:   13  Objects:        0 detected /        0 sextracted
# > Line:   14  Objects:        0 detected /        0 sextracted
# > Line:   15  Objects:        0 detected /        0 sextracted
# > Line:   16  Objects:        0 detected /        0 sextracted
# > Line:   17  Objects:        1 detected /        0 sextracted
# > Line:   18  Objects:        1 detected /        0 sextracted
# > Line:   19  Objects:        1 detected /        0 sextracted
# > Line:   20  Objects:        1 detected /        0 sextracted
# > Line:   21  Objects:        1 detected /        0 sextracted
# > Line:   22  Objects:        1 detected /        0 sextracted
# > Line:   23  Objects:        1 detected /        0 sextracted
# > Line:   24  Objects:        1 detected /        0 sextracted
# > Line:   25  Objects:        1 detected /        0 sextracted
# > Line:   26  Objects:        1 detected /        0 sextracted
# > Line:   27  Objects:        1 detected /        0 sextracted
# > Line:   28  Objects:        1 detected /        0 sextracted
# > Line:   29  Objects:        1 detected /        0 sextracted
# > Line:   30  Objects:        1 detected /        0 sextracted
# > Line:   31  Objects:        1 detected /        0 sextracted
# > Line:   32  Objects:        1 detected /        0 sextracted
# > Line:   33  Objects:        1 detected /        0 sextracted
# > Line:   34  Objects:        1 detected /        0 sextracted
# > Line:   35  Objects:        1 detected /        0 sextracted
# > Line:   36  Objects:        1 detected /        0 sextracted
# > Line:   37  Objects:        1 detected /        0 sextracted
# > Line:   38  Objects:        1 detected /        0 sextracted
# > Line:   39  Objects:        1 detected /        0 sextracted
# > Line:   40  Objects:        1 detected /        0 sextracted
# > Line:   41  Objects:        1 detected /        0 sextracted
# > Line:   42  Objects:        1 detected /        0 sextracted
# > Line:   43  Objects:        1 detected /        0 sextracted
# > Line:   44  Objects:        1 detected /        0 sextracted
# > Line:   45  Objects:        1 detected /        0 sextracted
# > Line:   46  Objects:        1 detected /        0 sextracted
# > Line:   47  Objects:        1 detected /        0 sextracted
# > Line:   48  Objects:        1 detected /        0 sextracted
# > Line:   49  Objects:        1 detected /        0 sextracted
# > Line:   50  Objects:        1 detected /        0 sextracted
# > Line:   51  Objects:        1 detected /        0 sextracted
# > Line:   52  Objects:        1 detected /        0 sextracted
# > Line:   53  Objects:        1 detected /        0 sextracted
# > Line:   54  Objects:        1 detected /        0 sextracted
# > Line:   55  Objects:        1 detected /        0 sextracted
# > Line:   56  Objects:        1 detected /        0 sextracted
# > Line:   57  Objects:        1 detected /        0 sextracted
# > Line:   58  Objects:        1 detected /        0 sextracted
# > Line:   59  Objects:        1 detected /        0 sextracted
# > Line:   60  Objects:        1 detected /        0 sextracted
# > Line:   61  Objects:        1 detected /        0 sextracted
# > Line:   62  Objects:        1 detected /        0 sextracted
# > Line:   63  Objects:        1 detected /        0 sextracted
# > Line:   64  Objects:        1 detected /        0 sextracted
# > Line:   65  Objects:        1 detected /        0 sextracted
# > Line:   66  Objects:        1 detected /        0 sextracted
# > Line:   67  Objects:        1 detected /        0 sextracted
# > Line:   68  Objects:        1 detected /        0 sextracted
# > Line:   69  Objects:        1 detected /        0 sextracted
# > Line:   70  Objects:        1 detected /        0 sextracted
# > Line:   71  Objects:        1 detected /        0 sextracted
# > Line:   72  Objects:        1 detected /        0 sextracted
# > Line:   73  Objects:        1 detected /        0 sextracted
# > Line:   74  Objects:        1 detected /        0 sextracted
# > Line:   75  Objects:        2 detected /        0 sextracted
# > Line:   76  Objects:        2 detected /        0 sextracted
# > Line:   77  Objects:        2 detected /        0 sextracted
# > Line:   78  Objects:        2 detected /        0 sextracted
# > Line:   79  Objects:        2 detected /        0 sextracted
# > Line:   80  Objects:        2 detected /        0 sextracted
# > Line:   81  Objects:        2 detected /        0 sextracted
# > Line:   82  Objects:        2 detected /        0 sextracted
# > Line:   83  Objects:        2 detected /        0 sextracted
# > Line:   84  Objects:        2 detected /        0 sextracted
# > Line:   85  Objects:        2 detected /        0 sextracted
# > Line:   86  Objects:        2 detected /        0 sextracted
# > Line:   87  Objects:        2 detected /        0 sextracted
# > Line:   88  Objects:        2 detected /        0 sextracted
# > Line:   89  Objects:        2 detected /        0 sextracted
# > Line:   90  Objects:        2 detected /        0 sextracted
# > Line:   91  Objects:        2 detected /        0 sextracted
# > Line:   92  Objects:        2 detected /        0 sextracted
# > Line:   93  Objects:        2 detected /        0 sextracted
# > Line:   94  Objects:        2 detected /        0 sextracted
# > Line:   95  Objects:        2 detected /        0 sextracted
# > Line:   96  Objects:        2 detected /        0 sextracted
# > Line:   97  Objects:        2 detected /        0 sextracted
# > Line:   98  Objects:        2 detected /        0 sextracted
# > Line:   99  Objects:        2 detected /        0 sextracted
# > Line:  100  Objects:        2 detected /        0 sextracted
# > Line:  101  Objects:        2 detected /        0 sextracted
# > Line:  102  Objects:        2 detected /        0 sextracted
# > Line:  103  Objects:        2 detected /        0 sextracted
# > Line:  104  Objects:        2 detected /        0 sextracted
# > Line:  105  Objects:        2 detected /        0 sextracted
# > Line:  106  Objects:        2 detected /        0 sextracted
# > Line:  107  Objects:        2 detected /        0 sextracted
# > Line:  108  Objects:        2 detected /        0 sextracted
# > Line:  109  Objects:        2 detected /        0 sextracted
# > Line:  110  Objects:        2 detected /        0 sextracted
# > Line:  111  Objects:        2 detected /        0 sextracted
# > Line:  112  Objects:        2 detected /        0 sextracted
# > Line:  113  Objects:        2 detected /        0 sextracted
# > Line:  114  Objects:        2 detected /        0 sextracted
# > Line:  115  Objects:        2 detected /        0 sextracted
# > Line:  116  Objects:        2 detected /        0 sextracted
# > Line:  117  Objects:        2 detected /        0 sextracted
# > Line:  118  Objects:        2 detected /        0 sextracted
# > Line:  119  Objects:        2 detected /        0 sextracted
# > Line:  120  Objects:        2 detected /        0 sextracted
# > Line:  121  Objects:        2 detected /        0 sextracted
# > Line:  122  Objects:        2 detected /        0 sextracted
# > Line:  123  Objects:        2 detected /        0 sextracted
# > Line:  124  Objects:        2 detected /        0 sextracted
# > Line:  125  Objects:        2 detected /        0 sextracted
# > Line:  126  Objects:        2 detected /        0 sextracted
# > Line:  127  Objects:        2 detected /        0 sextracted
# > Line:  128  Objects:        2 detected /        0 sextracted
# > Line:  129  Objects:        2 detected /        0 sextracted
# > Line:  130  Objects:        2 detected /        0 sextracted
# > Line:  131  Objects:        2 detected /        0 sextracted
# > Line:  132  Objects:        2 detected /        0 sextracted
# > Line:  133  Objects:        2 detected /        0 sextracted
# > Line:  134  Objects:        3 detected /        0 sextracted
# > Line:  135  Objects:        3 detected /        0 sextracted
# > Line:  136  Objects:        3 detected /        0 sextracted
# > Line:  137  Objects:        3 detected /        0 sextracted
# > Line:  138  Objects:        3 detected /        0 sextracted
# > Line:  139  Objects:        3 detected /        0 sextracted
# > Line:  140  Objects:        3 detected /        0 sextracted
# > Line:  141  Objects:        3 detected /        0 sextracted
# > Line:  142  Objects:        3 detected /        0 sextracted
# > Line:  143  Objects:        3 detected /        0 sextracted
# > Line:  144  Objects:        3 detected /        0 sextracted
# > Line:  145  Objects:        4 detected /        0 sextracted
# > Line:  146  Objects:        4 detected /        0 sextracted
# > Line:  147  Objects:        4 detected /        0 sextracted
# > Line:  148  Objects:        4 detected /        0 sextracted
# > Line:  149  Objects:        4 detected /        0 sextracted
# > Line:  150  Objects:        4 detected /        0 sextracted
# > Line:  151  Objects:        4 detected /        0 sextracted
# > Line:  152  Objects:        4 detected /        0 sextracted
# > Line:  153  Objects:        4 detected /        0 sextracted
# > Line:  154  Objects:        5 detected /        0 sextracted
# > Line:  155  Objects:        5 detected /        0 sextracted
# > Line:  156  Objects:        5 detected /        0 sextracted
# > Line:  157  Objects:        5 detected /        0 sextracted
# > Line:  158  Objects:        5 detected /        0 sextracted
# > Line:  159  Objects:        5 detected /        0 sextracted
# > Line:  160  Objects:        5 detected /        0 sextracted
# > Line:  161  Objects:        5 detected /        0 sextracted
# > Line:  162  Objects:        5 detected /        0 sextracted
# > Line:  163  Objects:        5 detected /        0 sextracted
# > Line:  164  Objects:        5 detected /        0 sextracted
# > Line:  165  Objects:        5 detected /        0 sextracted
# > Line:  166  Objects:        5 detected /        0 sextracted
# > Line:  167  Objects:        5 detected /        0 sextracted
# > Line:  168  Objects:        5 detected /        0 sextracted
# > Line:  169  Objects:        5 detected /        0 sextracted
# > Line:  170  Objects:        5 detected /        0 sextracted
# > Line:  171  Objects:        5 detected /        0 sextracted
# > Line:  172  Objects:        5 detected /        0 sextracted
# > Line:  173  Objects:        5 detected /        0 sextracted
# > Line:  174  Objects:        5 detected /        0 sextracted
# > Line:  175  Objects:        5 detected /        0 sextracted
# > Line:  176  Objects:        5 detected /        0 sextracted
# > Line:  177  Objects:        5 detected /        0 sextracted
# > Line:  178  Objects:        5 detected /        0 sextracted
# > Line:  179  Objects:        5 detected /        0 sextracted
# > Line:  180  Objects:        5 detected /        0 sextracted
# > Line:  181  Objects:        5 detected /        0 sextracted
# > Line:  182  Objects:        5 detected /        0 sextracted
# > Line:  183  Objects:        5 detected /        0 sextracted
# > Line:  184  Objects:        5 detected /        0 sextracted
# > Line:  185  Objects:        5 detected /        0 sextracted
# > Line:  186  Objects:        5 detected /        0 sextracted
# > Line:  187  Objects:        5 detected /        0 sextracted
# > Line:  188  Objects:        5 detected /        0 sextracted
# > Line:  189  Objects:        5 detected /        0 sextracted
# > Line:  190  Objects:        5 detected /        0 sextracted
# > Line:  191  Objects:        5 detected /        0 sextracted
# > Line:  192  Objects:        5 detected /        0 sextracted
# > Line:  193  Objects:        5 detected /        0 sextracted
# > Line:  194  Objects:        5 detected /        0 sextracted
# > Line:  195  Objects:        5 detected /        0 sextracted
# > Line:  196  Objects:        5 detected /        0 sextracted
# > Line:  197  Objects:        5 detected /        0 sextracted
# > Line:  198  Objects:        5 detected /        0 sextracted
# > Line:  199  Objects:        5 detected /        0 sextracted
# > Line:  200  Objects:        5 detected /        0 sextracted
# > Line:  201  Objects:        5 detected /        0 sextracted
# > Line:  202  Objects:        5 detected /        0 sextracted
# > Line:  203  Objects:        5 detected /        0 sextracted
# > Line:  204  Objects:        5 detected /        0 sextracted
# > Line:  205  Objects:        5 detected /        0 sextracted
# > Line:  206  Objects:        5 detected /        0 sextracted
# > Line:  207  Objects:        5 detected /        0 sextracted
# > Line:  208  Objects:        5 detected /        0 sextracted
# > Line:  209  Objects:        5 detected /        0 sextracted
# > Line:  210  Objects:        5 detected /        0 sextracted
# > Line:  211  Objects:        5 detected /        0 sextracted
# > Line:  212  Objects:        5 detected /        0 sextracted
# > Line:  213  Objects:        5 detected /        0 sextracted
# > Line:  214  Objects:        5 detected /        0 sextracted
# > Line:  215  Objects:        5 detected /        0 sextracted
# > Line:  216  Objects:        5 detected /        0 sextracted
# > Line:  217  Objects:        5 detected /        0 sextracted
# > Line:  218  Objects:        5 detected /        0 sextracted
# > Line:  219  Objects:        5 detected /        0 sextracted
# > Line:  220  Objects:        5 detected /        0 sextracted
# > Line:  221  Objects:        5 detected /        0 sextracted
# > Line:  222  Objects:        5 detected /        0 sextracted
# > Line:  223  Objects:        5 detected /        0 sextracted
# > Line:  224  Objects:        5 detected /        0 sextracted
# > Line:  225  Objects:        5 detected /        0 sextracted
# > Line:  226  Objects:        5 detected /        0 sextracted
# > Line:  227  Objects:        5 detected /        0 sextracted
# > Line:  228  Objects:        6 detected /        0 sextracted
# > Line:  229  Objects:        6 detected /        0 sextracted
# > Line:  230  Objects:        6 detected /        0 sextracted
# > Line:  231  Objects:        6 detected /        0 sextracted
# > Line:  232  Objects:        6 detected /        0 sextracted
# > Line:  233  Objects:        6 detected /        0 sextracted
# > Line:  234  Objects:        6 detected /        0 sextracted
# > Line:  235  Objects:        6 detected /        0 sextracted
# > Line:  236  Objects:        6 detected /        0 sextracted
# > Line:  237  Objects:        6 detected /        0 sextracted
# > Line:  238  Objects:        6 detected /        0 sextracted
# > Line:  239  Objects:        6 detected /        0 sextracted
# > Line:  240  Objects:        6 detected /        0 sextracted
# > Line:  241  Objects:        6 detected /        0 sextracted
# > Line:  242  Objects:        6 detected /        0 sextracted
# > Line:  243  Objects:        6 detected /        0 sextracted
# > Line:  244  Objects:        6 detected /        0 sextracted
# > Line:  245  Objects:        6 detected /        0 sextracted
# > Line:  246  Objects:        6 detected /        0 sextracted
# > Line:  247  Objects:        6 detected /        0 sextracted
# > Line:  248  Objects:        6 detected /        0 sextracted
# > Line:  249  Objects:        7 detected /        0 sextracted
# > Line:  250  Objects:        7 detected /        0 sextracted
# > Line:  251  Objects:        7 detected /        0 sextracted
# > Line:  252  Objects:        7 detected /        0 sextracted
# > Line:  253  Objects:        7 detected /        0 sextracted
# > Line:  254  Objects:        7 detected /        0 sextracted
# > Line:  255  Objects:        7 detected /        0 sextracted
# > Line:  256  Objects:        7 detected /        0 sextracted
# > Line:  257  Objects:        7 detected /        0 sextracted
# > Line:  258  Objects:        7 detected /        0 sextracted
# > Line:  259  Objects:        7 detected /        0 sextracted
# > Line:  260  Objects:        7 detected /        0 sextracted
# > Line:  261  Objects:        7 detected /        0 sextracted
# > Line:  262  Objects:        7 detected /        0 sextracted
# > Line:  263  Objects:        7 detected /        0 sextracted
# > Line:  264  Objects:        7 detected /        0 sextracted
# > Line:  265  Objects:        7 detected /        0 sextracted
# > Line:  266  Objects:        7 detected /        0 sextracted
# > Line:  267  Objects:        7 detected /        0 sextracted
# > Line:  268  Objects:        7 detected /        0 sextracted
# > Line:  269  Objects:        7 detected /        0 sextracted
# > Line:  270  Objects:        7 detected /        0 sextracted
# > Line:  271  Objects:        7 detected /        0 sextracted
# > Line:  272  Objects:        7 detected /        0 sextracted
# > Line:  273  Objects:        7 detected /        0 sextracted
# > Line:  274  Objects:        7 detected /        0 sextracted
# > Line:  275  Objects:        7 detected /        0 sextracted
# > Line:  276  Objects:        7 detected /        0 sextracted
# > Line:  277  Objects:        7 detected /        0 sextracted
# > Line:  278  Objects:        7 detected /        0 sextracted
# > Line:  279  Objects:        7 detected /        0 sextracted
# > Line:  280  Objects:        7 detected /        0 sextracted
# > Line:  281  Objects:        7 detected /        0 sextracted
# > Line:  282  Objects:        7 detected /        0 sextracted
# > Line:  283  Objects:        7 detected /        0 sextracted
# > Line:  284  Objects:        7 detected /        0 sextracted
# > Line:  285  Objects:        7 detected /        0 sextracted
# > Line:  286  Objects:        7 detected /        0 sextracted
# > Line:  287  Objects:        7 detected /        0 sextracted
# > Line:  288  Objects:        7 detected /        0 sextracted
# > Line:  289  Objects:        7 detected /        0 sextracted
# > Line:  290  Objects:        7 detected /        0 sextracted
# > Line:  291  Objects:        7 detected /        0 sextracted
# > Line:  292  Objects:        7 detected /        0 sextracted
# > Line:  293  Objects:        7 detected /        0 sextracted
# > Line:  294  Objects:        7 detected /        0 sextracted
# > Line:  295  Objects:        7 detected /        0 sextracted
# > Line:  296  Objects:        7 detected /        0 sextracted
# > Line:  297  Objects:        7 detected /        0 sextracted
# > Line:  298  Objects:        7 detected /        0 sextracted
# > Line:  299  Objects:        7 detected /        0 sextracted
# > Line:  300  Objects:        7 detected /        0 sextracted
# > Line:  301  Objects:        7 detected /        0 sextracted
# > Line:  302  Objects:        7 detected /        0 sextracted
# > Line:  303  Objects:        7 detected /        0 sextracted
# > Line:  304  Objects:        7 detected /        0 sextracted
# > Line:  305  Objects:        7 detected /        0 sextracted
# > Line:  306  Objects:        8 detected /        0 sextracted
# > Line:  307  Objects:        8 detected /        0 sextracted
# > Line:  308  Objects:        8 detected /        0 sextracted
# > Line:  309  Objects:        8 detected /        0 sextracted
# > Line:  310  Objects:        8 detected /        0 sextracted
# > Line:  311  Objects:        8 detected /        0 sextracted
# > Line:  312  Objects:        8 detected /        0 sextracted
# > Line:  313  Objects:        8 detected /        0 sextracted
# > Line:  314  Objects:        8 detected /        0 sextracted
# > Line:  315  Objects:        8 detected /        0 sextracted
# > Line:  316  Objects:        8 detected /        0 sextracted
# > Line:  317  Objects:        8 detected /        0 sextracted
# > Line:  318  Objects:        8 detected /        0 sextracted
# > Line:  319  Objects:        8 detected /        0 sextracted
# > Line:  320  Objects:        8 detected /        0 sextracted
# > Line:  321  Objects:        8 detected /        0 sextracted
# > Line:  322  Objects:        8 detected /        0 sextracted
# > Line:  323  Objects:        8 detected /        0 sextracted
# > Line:  324  Objects:        8 detected /        0 sextracted
# > Line:  325  Objects:        8 detected /        0 sextracted
# > Line:  326  Objects:        8 detected /        0 sextracted
# > Line:  327  Objects:        8 detected /        0 sextracted
# > Line:  328  Objects:        8 detected /        0 sextracted
# > Line:  329  Objects:        8 detected /        0 sextracted
# > Line:  330  Objects:        8 detected /        0 sextracted
# > Line:  331  Objects:        8 detected /        0 sextracted
# > Line:  332  Objects:        8 detected /        0 sextracted
# > Line:  333  Objects:        8 detected /        0 sextracted
# > Line:  334  Objects:        8 detected /        0 sextracted
# > Line:  335  Objects:        8 detected /        0 sextracted
# > Line:  336  Objects:        8 detected /        0 sextracted
# > Line:  337  Objects:        8 detected /        0 sextracted
# > Line:  338  Objects:        8 detected /        0 sextracted
# > Line:  339  Objects:        8 detected /        0 sextracted
# > Line:  340  Objects:        8 detected /        0 sextracted
# > Line:  341  Objects:        8 detected /        0 sextracted
# > Line:  342  Objects:        8 detected /        0 sextracted
# > Line:  343  Objects:        8 detected /        0 sextracted
# > Line:  344  Objects:        8 detected /        0 sextracted
# > Line:  345  Objects:        8 detected /        0 sextracted
# > Line:  346  Objects:        8 detected /        0 sextracted
# > Line:  347  Objects:        8 detected /        0 sextracted
# > Line:  348  Objects:        8 detected /        0 sextracted
# > Line:  349  Objects:        8 detected /        0 sextracted
# > Line:  350  Objects:        8 detected /        0 sextracted
# > Line:  351  Objects:        8 detected /        0 sextracted
# > Line:  352  Objects:        8 detected /        0 sextracted
# > Line:  353  Objects:        8 detected /        0 sextracted
# > Line:  354  Objects:        8 detected /        0 sextracted
# > Line:  355  Objects:        8 detected /        0 sextracted
# > Line:  356  Objects:        8 detected /        0 sextracted
# > Line:  357  Objects:        8 detected /        0 sextracted
# > Line:  358  Objects:        8 detected /        0 sextracted
# > Line:  359  Objects:        8 detected /        0 sextracted
# > Line:  360  Objects:        8 detected /        0 sextracted
# > Line:  361  Objects:        9 detected /        0 sextracted
# > Line:  362  Objects:        9 detected /        0 sextracted
# > Line:  363  Objects:       10 detected /        0 sextracted
# > Line:  364  Objects:       10 detected /        0 sextracted
# > Line:  365  Objects:       10 detected /        0 sextracted
# > Line:  366  Objects:       10 detected /        0 sextracted
# > Line:  367  Objects:       10 detected /        0 sextracted
# > Line:  368  Objects:       10 detected /        0 sextracted
# > Line:  369  Objects:       10 detected /        0 sextracted
# > Line:  370  Objects:       10 detected /        0 sextracted
# > Line:  371  Objects:       10 detected /        0 sextracted
# > Line:  372  Objects:       10 detected /        0 sextracted
# > Line:  373  Objects:       10 detected /        0 sextracted
# > Line:  374  Objects:       10 detected /        0 sextracted
# > Line:  375  Objects:       10 detected /        0 sextracted
# > Line:  376  Objects:       10 detected /        0 sextracted
# > Line:  377  Objects:       10 detected /        0 sextracted
# > Line:  378  Objects:       10 detected /        0 sextracted
# > Line:  379  Objects:       10 detected /        0 sextracted
# > Line:  380  Objects:       10 detected /        0 sextracted
# > Line:  381  Objects:       10 detected /        0 sextracted
# > Line:  382  Objects:       10 detected /        0 sextracted
# > Line:  383  Objects:       10 detected /        0 sextracted
# > Line:  384  Objects:       10 detected /        0 sextracted
# > Line:  385  Objects:       10 detected /        0 sextracted
# > Line:  386  Objects:       10 detected /        0 sextracted
# > Line:  387  Objects:       10 detected /        0 sextracted
# > Line:  388  Objects:       10 detected /        0 sextracted
# > Line:  389  Objects:       10 detected /        0 sextracted
# > Line:  390  Objects:       10 detected /        0 sextracted
# > Line:  391  Objects:       10 detected /        0 sextracted
# > Line:  392  Objects:       10 detected /        0 sextracted
# > Line:  393  Objects:       10 detected /        0 sextracted
# > Line:  394  Objects:       10 detected /        0 sextracted
# > Line:  395  Objects:       10 detected /        0 sextracted
# > Line:  396  Objects:       10 detected /        0 sextracted
# > Line:  397  Objects:       10 detected /        0 sextracted
# > Line:  398  Objects:       10 detected /        0 sextracted
# > Line:  399  Objects:       10 detected /        0 sextracted
# > Line:  400  Objects:       10 detected /        0 sextracted
# > Line:  401  Objects:       11 detected /        0 sextracted
# > Line:  402  Objects:       11 detected /        0 sextracted
# > Line:  403  Objects:       11 detected /        0 sextracted
# > Line:  404  Objects:       11 detected /        0 sextracted
# > Line:  405  Objects:       11 detected /        0 sextracted
# > Line:  406  Objects:       11 detected /        0 sextracted
# > Line:  407  Objects:       11 detected /        0 sextracted
# > Line:  408  Objects:       12 detected /        0 sextracted
# > Line:  409  Objects:       12 detected /        0 sextracted
# > Line:  410  Objects:       12 detected /        0 sextracted
# > Line:  411  Objects:       12 detected /        0 sextracted
# > Line:  412  Objects:       12 detected /        0 sextracted
# > Line:  413  Objects:       12 detected /        0 sextracted
# > Line:  414  Objects:       12 detected /        0 sextracted
# > Line:  415  Objects:       12 detected /        0 sextracted
# > Line:  416  Objects:       12 detected /        0 sextracted
# > Line:  417  Objects:       12 detected /        0 sextracted
# > Line:  418  Objects:       12 detected /        0 sextracted
# > Line:  419  Objects:       12 detected /        0 sextracted
# > Line:  420  Objects:       12 detected /        0 sextracted
# > Line:  421  Objects:       12 detected /        0 sextracted
# > Line:  422  Objects:       12 detected /        0 sextracted
# > Line:  423  Objects:       12 detected /        0 sextracted
# > Line:  424  Objects:       12 detected /        0 sextracted
# > Line:  425  Objects:       12 detected /        0 sextracted
# > Line:  426  Objects:       12 detected /        0 sextracted
# > Line:  427  Objects:       12 detected /        0 sextracted
# > Line:  428  Objects:       12 detected /        0 sextracted
# > Line:  429  Objects:       12 detected /        0 sextracted
# > Line:  430  Objects:       12 detected /        0 sextracted
# > Line:  431  Objects:       12 detected /        0 sextracted
# > Line:  432  Objects:       12 detected /        0 sextracted
# > Line:  433  Objects:       12 detected /        0 sextracted
# > Line:  434  Objects:       12 detected /        0 sextracted
# > Line:  435  Objects:       12 detected /        0 sextracted
# > Line:  436  Objects:       12 detected /        0 sextracted
# > Line:  437  Objects:       13 detected /        0 sextracted
# > Line:  438  Objects:       13 detected /        0 sextracted
# > Line:  439  Objects:       13 detected /        0 sextracted
# > Line:  440  Objects:       13 detected /        0 sextracted
# > Line:  441  Objects:       13 detected /        0 sextracted
# > Line:  442  Objects:       13 detected /        0 sextracted
# > Line:  443  Objects:       13 detected /        0 sextracted
# > Line:  444  Objects:       13 detected /        0 sextracted
# > Line:  445  Objects:       13 detected /        0 sextracted
# > Line:  446  Objects:       13 detected /        0 sextracted
# > Line:  447  Objects:       13 detected /        0 sextracted
# > Line:  448  Objects:       13 detected /        0 sextracted
# > Line:  449  Objects:       13 detected /        0 sextracted
# > Line:  450  Objects:       13 detected /        0 sextracted
# > Line:  451  Objects:       13 detected /        0 sextracted
# > Line:  452  Objects:       13 detected /        0 sextracted
# > Line:  453  Objects:       13 detected /        0 sextracted
# > Line:  454  Objects:       13 detected /        0 sextracted
# > Line:  455  Objects:       13 detected /        0 sextracted
# > Line:  456  Objects:       13 detected /        0 sextracted
# > Line:  457  Objects:       13 detected /        0 sextracted
# > Line:  458  Objects:       13 detected /        0 sextracted
# > Line:  459  Objects:       13 detected /        0 sextracted
# > Line:  460  Objects:       13 detected /        0 sextracted
# > Line:  461  Objects:       13 detected /        0 sextracted
# > Line:  462  Objects:       13 detected /        0 sextracted
# > Line:  463  Objects:       13 detected /        0 sextracted
# > Line:  464  Objects:       13 detected /        0 sextracted
# > Line:  465  Objects:       13 detected /        0 sextracted
# > Line:  466  Objects:       13 detected /        0 sextracted
# > Line:  467  Objects:       13 detected /        0 sextracted
# > Line:  468  Objects:       13 detected /        0 sextracted
# > Line:  469  Objects:       13 detected /        0 sextracted
# > Line:  470  Objects:       13 detected /        0 sextracted
# > Line:  471  Objects:       13 detected /        0 sextracted
# > Line:  472  Objects:       13 detected /        0 sextracted
# > Line:  473  Objects:       13 detected /        0 sextracted
# > Line:  474  Objects:       13 detected /        0 sextracted
# > Line:  475  Objects:       13 detected /        0 sextracted
# > Line:  476  Objects:       13 detected /        0 sextracted
# > Line:  477  Objects:       13 detected /        0 sextracted
# > Line:  478  Objects:       13 detected /        0 sextracted
# > Line:  479  Objects:       13 detected /        0 sextracted
# > Line:  480  Objects:       13 detected /        0 sextracted
# > Line:  481  Objects:       13 detected /        0 sextracted
# > Line:  482  Objects:       13 detected /        0 sextracted
# > Line:  483  Objects:       13 detected /        0 sextracted
# > Line:  484  Objects:       13 detected /        0 sextracted
# > Line:  485  Objects:       13 detected /        0 sextracted
# > Line:  486  Objects:       13 detected /        0 sextracted
# > Line:  487  Objects:       13 detected /        0 sextracted
# > Line:  488  Objects:       13 detected /        0 sextracted
# > Line:  489  Objects:       13 detected /        0 sextracted
# > Line:  490  Objects:       13 detected /        0 sextracted
# > Line:  491  Objects:       13 detected /        0 sextracted
# > Line:  492  Objects:       13 detected /        0 sextracted
# > Line:  493  Objects:       13 detected /        0 sextracted
# > Line:  494  Objects:       13 detected /        0 sextracted
# > Line:  495  Objects:       13 detected /        0 sextracted
# > Line:  496  Objects:       13 detected /        0 sextracted
# > Line:  497  Objects:       14 detected /        0 sextracted
# > Line:  498  Objects:       14 detected /        0 sextracted
# > Line:  499  Objects:       14 detected /        0 sextracted
# > Line:  500  Objects:       14 detected /        0 sextracted
# > Line:  501  Objects:       14 detected /        0 sextracted
# > Line:  502  Objects:       14 detected /        0 sextracted
# > Line:  503  Objects:       14 detected /        0 sextracted
# > Line:  504  Objects:       14 detected /        0 sextracted
# > Line:  505  Objects:       14 detected /        0 sextracted
# > Line:  506  Objects:       14 detected /        0 sextracted
# > Line:  507  Objects:       14 detected /        0 sextracted
# > Line:  508  Objects:       15 detected /        0 sextracted
# > Line:  509  Objects:       15 detected /        0 sextracted
# > Line:  510  Objects:       15 detected /        0 sextracted
# > Line:  511  Objects:       15 detected /        0 sextracted
# > Line:  512  Objects:       15 detected /        0 sextracted
# > Line:  513  Objects:       15 detected /        0 sextracted
# > Line:  514  Objects:       15 detected /        0 sextracted
# > Line:  515  Objects:       16 detected /        0 sextracted
# > Line:  516  Objects:       17 detected /        0 sextracted
# > Line:  517  Objects:       17 detected /        0 sextracted
# > Line:  518  Objects:       17 detected /        0 sextracted
# > Line:  519  Objects:       17 detected /        0 sextracted
# > Line:  520  Objects:       17 detected /        0 sextracted
# > Line:  521  Objects:       17 detected /        0 sextracted
# > Line:  522  Objects:       17 detected /        0 sextracted
# > Line:  523  Objects:       17 detected /        0 sextracted
# > Line:  524  Objects:       17 detected /        0 sextracted
# > Line:  525  Objects:       17 detected /        0 sextracted
# > Line:  526  Objects:       17 detected /        0 sextracted
# > Line:  527  Objects:       17 detected /        0 sextracted
# > Line:  528  Objects:       17 detected /        0 sextracted
# > Line:  529  Objects:       17 detected /        0 sextracted
# > Line:  530  Objects:       17 detected /        0 sextracted
# > Line:  531  Objects:       17 detected /        0 sextracted
# > Line:  532  Objects:       17 detected /        0 sextracted
# > Line:  533  Objects:       17 detected /        0 sextracted
# > Line:  534  Objects:       17 detected /        0 sextracted
# > Line:  535  Objects:       17 detected /        0 sextracted
# > Line:  536  Objects:       17 detected /        0 sextracted
# > Line:  537  Objects:       17 detected /        0 sextracted
# > Line:  538  Objects:       18 detected /        0 sextracted
# > Line:  539  Objects:       18 detected /        0 sextracted
# > Line:  540  Objects:       18 detected /        0 sextracted
# > Line:  541  Objects:       18 detected /        0 sextracted
# > Line:  542  Objects:       19 detected /        0 sextracted
# > Line:  543  Objects:       19 detected /        0 sextracted
# > Line:  544  Objects:       19 detected /        0 sextracted
# > Line:  545  Objects:       19 detected /        0 sextracted
# > Line:  546  Objects:       19 detected /        0 sextracted
# > Line:  547  Objects:       19 detected /        0 sextracted
# > Line:  548  Objects:       19 detected /        0 sextracted
# > Line:  549  Objects:       19 detected /        0 sextracted
# > Line:  550  Objects:       19 detected /        0 sextracted
# > Line:  551  Objects:       19 detected /        0 sextracted
# > Line:  552  Objects:       19 detected /        0 sextracted
# > Line:  553  Objects:       19 detected /        0 sextracted
# > Line:  554  Objects:       19 detected /        0 sextracted
# > Line:  555  Objects:       19 detected /        0 sextracted
# > Line:  556  Objects:       19 detected /        0 sextracted
# > Line:  557  Objects:       19 detected /        0 sextracted
# > Line:  558  Objects:       19 detected /        0 sextracted
# > Line:  559  Objects:       19 detected /        0 sextracted
# > Line:  560  Objects:       19 detected /        0 sextracted
# > Line:  561  Objects:       19 detected /        0 sextracted
# > Line:  562  Objects:       19 detected /        0 sextracted
# > Line:  563  Objects:       19 detected /        0 sextracted
# > Line:  564  Objects:       19 detected /        0 sextracted
# > Line:  565  Objects:       19 detected /        0 sextracted
# > Line:  566  Objects:       19 detected /        0 sextracted
# > Line:  567  Objects:       19 detected /        0 sextracted
# > Line:  568  Objects:       19 detected /        0 sextracted
# > Line:  569  Objects:       19 detected /        0 sextracted
# > Line:  570  Objects:       19 detected /        0 sextracted
# > Line:  571  Objects:       19 detected /        0 sextracted
# > Line:  572  Objects:       19 detected /        0 sextracted
# > Line:  573  Objects:       19 detected /        0 sextracted
# > Line:  574  Objects:       19 detected /        0 sextracted
# > Line:  575  Objects:       19 detected /        0 sextracted
# > Line:  576  Objects:       19 detected /        0 sextracted
# > Line:  577  Objects:       19 detected /        0 sextracted
# > Line:  578  Objects:       19 detected /        0 sextracted
# > Line:  579  Objects:       19 detected /        0 sextracted
# > Line:  580  Objects:       19 detected /        0 sextracted
# > Line:  581  Objects:       19 detected /        0 sextracted
# > Line:  582  Objects:       19 detected /        0 sextracted
# > Line:  583  Objects:       19 detected /        0 sextracted
# > Line:  584  Objects:       19 detected /        0 sextracted
# > Line:  585  Objects:       19 detected /        0 sextracted
# > Line:  586  Objects:       19 detected /        0 sextracted
# > Line:  587  Objects:       19 detected /        0 sextracted
# > Line:  588  Objects:       19 detected /        0 sextracted
# > Line:  589  Objects:       19 detected /        0 sextracted
# > Line:  590  Objects:       19 detected /        0 sextracted
# > Line:  591  Objects:       19 detected /        0 sextracted
# > Line:  592  Objects:       19 detected /        0 sextracted
# > Line:  593  Objects:       19 detected /        0 sextracted
# > Line:  594  Objects:       19 detected /        0 sextracted
# > Line:  595  Objects:       19 detected /        0 sextracted
# > Line:  596  Objects:       19 detected /        0 sextracted
# > Line:  597  Objects:       19 detected /        0 sextracted
# > Line:  598  Objects:       19 detected /        0 sextracted
# > Line:  599  Objects:       19 detected /        0 sextracted
# > Line:  600  Objects:       19 detected /        0 sextracted
# > Line:  601  Objects:       19 detected /        0 sextracted
# > Line:  602  Objects:       19 detected /        0 sextracted
# > Line:  603  Objects:       19 detected /        0 sextracted
# > Line:  604  Objects:       19 detected /        0 sextracted
# > Line:  605  Objects:       19 detected /        0 sextracted
# > Line:  606  Objects:       19 detected /        0 sextracted
# > Line:  607  Objects:       19 detected /        0 sextracted
# > Line:  608  Objects:       19 detected /        0 sextracted
# > Line:  609  Objects:       19 detected /        0 sextracted
# > Line:  610  Objects:       19 detected /        0 sextracted
# > Line:  611  Objects:       19 detected /        0 sextracted
# > Line:  612  Objects:       19 detected /        0 sextracted
# > Line:  613  Objects:       19 detected /        0 sextracted
# > Line:  614  Objects:       19 detected /        0 sextracted
# > Line:  615  Objects:       19 detected /        0 sextracted
# > Line:  616  Objects:       19 detected /        0 sextracted
# > Line:  617  Objects:       19 detected /        0 sextracted
# > Line:  618  Objects:       19 detected /        0 sextracted
# > Line:  619  Objects:       19 detected /        0 sextracted
# > Line:  620  Objects:       19 detected /        0 sextracted
# > Line:  621  Objects:       19 detected /        0 sextracted
# > Line:  622  Objects:       19 detected /        0 sextracted
# > Line:  623  Objects:       19 detected /        0 sextracted
# > Line:  624  Objects:       19 detected /        0 sextracted
# > Line:  625  Objects:       19 detected /        0 sextracted
# > Line:  626  Objects:       19 detected /        0 sextracted
# > Line:  627  Objects:       19 detected /        0 sextracted
# > Line:  628  Objects:       19 detected /        0 sextracted
# > Line:  629  Objects:       19 detected /        0 sextracted
# > Line:  630  Objects:       19 detected /        0 sextracted
# > Line:  631  Objects:       19 detected /        0 sextracted
# > Line:  632  Objects:       19 detected /        0 sextracted
# > Line:  633  Objects:       19 detected /        0 sextracted
# > Line:  634  Objects:       19 detected /        0 sextracted
# > Line:  635  Objects:       19 detected /        0 sextracted
# > Line:  636  Objects:       19 detected /        0 sextracted
# > Line:  637  Objects:       19 detected /        0 sextracted
# > Line:  638  Objects:       19 detected /        0 sextracted
# > Line:  639  Objects:       19 detected /        0 sextracted
# > Line:  640  Objects:       19 detected /        0 sextracted
# > Line:  641  Objects:       19 detected /        0 sextracted
# > Line:  642  Objects:       19 detected /        0 sextracted
# > Line:  643  Objects:       19 detected /        0 sextracted
# > Line:  644  Objects:       19 detected /        0 sextracted
# > Line:  645  Objects:       20 detected /        0 sextracted
# > Line:  646  Objects:       20 detected /        0 sextracted
# > Line:  647  Objects:       20 detected /        0 sextracted
# > Line:  648  Objects:       20 detected /        0 sextracted
# > Line:  649  Objects:       20 detected /        0 sextracted
# > Line:  650  Objects:       20 detected /        0 sextracted
# > Line:  651  Objects:       20 detected /        0 sextracted
# > Line:  652  Objects:       20 detected /        0 sextracted
# > Line:  653  Objects:       20 detected /        0 sextracted
# > Line:  654  Objects:       20 detected /        0 sextracted
# > Line:  655  Objects:       20 detected /        0 sextracted
# > Line:  656  Objects:       20 detected /        0 sextracted
# > Line:  657  Objects:       20 detected /        0 sextracted
# > Line:  658  Objects:       20 detected /        0 sextracted
# > Line:  659  Objects:       20 detected /        0 sextracted
# > Line:  660  Objects:       20 detected /        0 sextracted
# > Line:  661  Objects:       20 detected /        0 sextracted
# > Line:  662  Objects:       20 detected /        0 sextracted
# > Line:  663  Objects:       21 detected /        0 sextracted
# > Line:  664  Objects:       21 detected /        0 sextracted
# > Line:  665  Objects:       21 detected /        0 sextracted
# > Line:  666  Objects:       21 detected /        0 sextracted
# > Line:  667  Objects:       21 detected /        0 sextracted
# > Line:  668  Objects:       21 detected /        0 sextracted
# > Line:  669  Objects:       21 detected /        0 sextracted
# > Line:  670  Objects:       21 detected /        0 sextracted
# > Line:  671  Objects:       21 detected /        0 sextracted
# > Line:  672  Objects:       21 detected /        0 sextracted
# > Line:  673  Objects:       22 detected /        0 sextracted
# > Line:  674  Objects:       22 detected /        0 sextracted
# > Line:  675  Objects:       22 detected /        0 sextracted
# > Line:  676  Objects:       22 detected /        0 sextracted
# > Line:  677  Objects:       22 detected /        0 sextracted
# > Line:  678  Objects:       22 detected /        0 sextracted
# > Line:  679  Objects:       22 detected /        0 sextracted
# > Line:  680  Objects:       22 detected /        0 sextracted
# > Line:  681  Objects:       22 detected /        0 sextracted
# > Line:  682  Objects:       22 detected /        0 sextracted
# > Line:  683  Objects:       22 detected /        0 sextracted
# > Line:  684  Objects:       23 detected /        0 sextracted
# > Line:  685  Objects:       23 detected /        0 sextracted
# > Line:  686  Objects:       23 detected /        0 sextracted
# > Line:  687  Objects:       23 detected /        0 sextracted
# > Line:  688  Objects:       23 detected /        0 sextracted
# > Line:  689  Objects:       23 detected /        0 sextracted
# > Line:  690  Objects:       23 detected /        0 sextracted
# > Line:  691  Objects:       23 detected /        0 sextracted
# > Line:  692  Objects:       23 detected /        0 sextracted
# > Line:  693  Objects:       23 detected /        0 sextracted
# > Line:  694  Objects:       23 detected /        0 sextracted
# > Line:  695  Objects:       23 detected /        0 sextracted
# > Line:  696  Objects:       23 detected /        0 sextracted
# > Line:  697  Objects:       23 detected /        0 sextracted
# > Line:  698  Objects:       23 detected /        0 sextracted
# > Line:  699  Objects:       23 detected /        0 sextracted
# > Line:  700  Objects:       24 detected /        0 sextracted
# > Line:  701  Objects:       24 detected /        0 sextracted
# > Line:  702  Objects:       24 detected /        0 sextracted
# > Line:  703  Objects:       25 detected /        0 sextracted
# > Line:  704  Objects:       25 detected /        0 sextracted
# > Line:  705  Objects:       25 detected /        0 sextracted
# > Line:  706  Objects:       25 detected /        0 sextracted
# > Line:  707  Objects:       25 detected /        0 sextracted
# > Line:  708  Objects:       25 detected /        0 sextracted
# > Line:  709  Objects:       25 detected /        0 sextracted
# > Line:  710  Objects:       25 detected /        0 sextracted
# > Line:  711  Objects:       25 detected /        0 sextracted
# > Line:  712  Objects:       25 detected /        0 sextracted
# > Line:  713  Objects:       25 detected /        0 sextracted
# > Line:  714  Objects:       25 detected /        0 sextracted
# > Line:  715  Objects:       25 detected /        0 sextracted
# > Line:  716  Objects:       25 detected /        0 sextracted
# > Line:  717  Objects:       25 detected /        0 sextracted
# > Line:  718  Objects:       25 detected /        0 sextracted
# > Line:  719  Objects:       25 detected /        0 sextracted
# > Line:  720  Objects:       25 detected /        0 sextracted
# > Line:  721  Objects:       25 detected /        0 sextracted
# > Line:  722  Objects:       25 detected /        0 sextracted
# > Line:  723  Objects:       25 detected /        0 sextracted
# > Line:  724  Objects:       25 detected /        0 sextracted
# > Line:  725  Objects:       25 detected /        0 sextracted
# > Line:  726  Objects:       25 detected /        0 sextracted
# > Line:  727  Objects:       25 detected /        0 sextracted
# > Line:  728  Objects:       25 detected /        0 sextracted
# > Line:  729  Objects:       25 detected /        0 sextracted
# > Line:  730  Objects:       25 detected /        0 sextracted
# > Line:  731  Objects:       25 detected /        0 sextracted
# > Line:  732  Objects:       25 detected /        0 sextracted
# > Line:  733  Objects:       25 detected /        0 sextracted
# > Line:  734  Objects:       25 detected /        0 sextracted
# > Line:  735  Objects:       25 detected /        0 sextracted
# > Line:  736  Objects:       25 detected /        0 sextracted
# > Line:  737  Objects:       25 detected /        0 sextracted
# > Line:  738  Objects:       25 detected /        0 sextracted
# > Line:  739  Objects:       25 detected /        0 sextracted
# > Line:  740  Objects:       25 detected /        0 sextracted
# > Line:  741  Objects:       25 detected /        0 sextracted
# > Line:  742  Objects:       25 detected /        0 sextracted
# > Line:  743  Objects:       25 detected /        0 sextracted
# > Line:  744  Objects:       25 detected /        0 sextracted
# ...
# > Line: 1979  Objects:       82 detected /       40 sextracted
# > Line: 1980  Objects:       82 detected /       40 sextracted
# > Line: 1981  Objects:       82 detected /       40 sextracted
# > Line: 1982  Objects:       82 detected /       40 sextracted
# > Line: 1983  Objects:       82 detected /       40 sextracted
# > Line: 1984  Objects:       82 detected /       40 sextracted
# > Line: 1985  Objects:       82 detected /       40 sextracted
# > Line: 1986  Objects:       82 detected /       40 sextracted
# > Line: 1987  Objects:       82 detected /       40 sextracted
# > Line: 1988  Objects:       82 detected /       40 sextracted
# > Line: 1989  Objects:       82 detected /       40 sextracted
# > Line: 1990  Objects:       82 detected /       40 sextracted
# > Line: 1991  Objects:       82 detected /       40 sextracted
# > Line: 1992  Objects:       82 detected /       40 sextracted
# > Line: 1993  Objects:       82 detected /       40 sextracted
# > Line: 1994  Objects:       82 detected /       40 sextracted
# > Line: 1995  Objects:       82 detected /       40 sextracted
# > Line: 1996  Objects:       82 detected /       40 sextracted
# > Line: 1997  Objects:       82 detected /       40 sextracted
# > Line: 1998  Objects:       82 detected /       40 sextracted
# > Line: 1999  Objects:       82 detected /       40 sextracted
# > Line: 2000  Objects:       82 detected /       40 sextracted
# > Line: 2001  Objects:       82 detected /       40 sextracted
# > Line: 2002  Objects:       82 detected /       40 sextracted
# > Line: 2003  Objects:       82 detected /       40 sextracted
# > Line: 2004  Objects:       82 detected /       40 sextracted
# > Line: 2005  Objects:       82 detected /       40 sextracted
# > Line: 2006  Objects:       82 detected /       40 sextracted
# > Line: 2007  Objects:       82 detected /       40 sextracted
# > Line: 2008  Objects:       82 detected /       40 sextracted
# > Line: 2009  Objects:       82 detected /       40 sextracted
# > Line: 2010  Objects:       82 detected /       40 sextracted
# > Line: 2011  Objects:       82 detected /       40 sextracted
# > Line: 2012  Objects:       82 detected /       40 sextracted
# > Line: 2013  Objects:       82 detected /       40 sextracted
# > Line: 2014  Objects:       82 detected /       40 sextracted
# > Line: 2015  Objects:       82 detected /       40 sextracted
# > Line: 2016  Objects:       82 detected /       40 sextracted
# > Line: 2017  Objects:       82 detected /       40 sextracted
# > Line: 2018  Objects:       82 detected /       40 sextracted
# > Line: 2019  Objects:       82 detected /       40 sextracted
# > Line: 2020  Objects:       82 detected /       40 sextracted
# > Line: 2021  Objects:       82 detected /       40 sextracted
# > Line: 2022  Objects:       82 detected /       40 sextracted
# > Line: 2023  Objects:       82 detected /       40 sextracted
# > Line: 2024  Objects:       82 detected /       40 sextracted
# > Line: 2025  Objects:       82 detected /       40 sextracted
# > Line: 2026  Objects:       82 detected /       40 sextracted
# > Line: 2027  Objects:       82 detected /       40 sextracted
# > Line: 2028  Objects:       82 detected /       40 sextracted
# > Line: 2029  Objects:       82 detected /       40 sextracted
# > Line: 2030  Objects:       82 detected /       40 sextracted
# > Line: 2031  Objects:       82 detected /       40 sextracted
# > Line: 2032  Objects:       82 detected /       40 sextracted
# > Line: 2033  Objects:       82 detected /       40 sextracted
# > Line: 2034  Objects:       82 detected /       40 sextracted
# > Line: 2035  Objects:       82 detected /       40 sextracted
# > Line: 2036  Objects:       82 detected /       40 sextracted
# > Line: 2037  Objects:       82 detected /       40 sextracted
# > Line: 2038  Objects:       82 detected /       40 sextracted
# > Line: 2039  Objects:       82 detected /       40 sextracted
# > Line: 2040  Objects:       82 detected /       40 sextracted
# > Line: 2041  Objects:       82 detected /       40 sextracted
# > Line: 2042  Objects:       82 detected /       40 sextracted
# > Line: 2043  Objects:       82 detected /       40 sextracted
# > Line: 2044  Objects:       82 detected /       40 sextracted
# > Line: 2045  Objects:       82 detected /       40 sextracted
# > Line: 2046  Objects:       82 detected /       40 sextracted
# > Line: 2047  Objects:       82 detected /       40 sextracted
# > Line: 2048  Objects:       82 detected /       40 sextracted
# > Line: 2049  Objects:       82 detected /       40 sextracted
# > Line: 2050  Objects:       82 detected /       40 sextracted
# > Line: 2051  Objects:       82 detected /       40 sextracted
# > Line: 2052  Objects:       82 detected /       40 sextracted
# > Line: 2053  Objects:       82 detected /       40 sextracted
# > Line: 2054  Objects:       82 detected /       40 sextracted
# > Line: 2055  Objects:       82 detected /       40 sextracted
# > Line: 2056  Objects:       82 detected /       40 sextracted
# > Line: 2075  Objects:       83 detected /       42 sextracted
# > Line: 2100  Objects:       85 detected /       44 sextracted
# > Line: 2125  Objects:       87 detected /       46 sextracted
# > Line: 2150  Objects:       88 detected /       46 sextracted
# > Line: 2175  Objects:       88 detected /       46 sextracted
# > Line: 2200  Objects:       89 detected /       47 sextracted
# > Line: 2225  Objects:       90 detected /       47 sextracted
# > Line: 2250  Objects:       93 detected /       47 sextracted
# > Line: 2275  Objects:       94 detected /       49 sextracted
# > Line: 2283  Objects:       94 detected /       50 sextracted
# > Line: 2284  Objects:       94 detected /       50 sextracted
# > Line: 2285  Objects:       94 detected /       50 sextracted
# > Line: 2300  Objects:       96 detected /       51 sextracted
# > Line: 2325  Objects:       97 detected /       51 sextracted
# > Line: 2350  Objects:       98 detected /       51 sextracted
# > Line: 2375  Objects:      101 detected /       52 sextracted
# > Line: 2400  Objects:      102 detected /       53 sextracted
# > Line: 2425  Objects:      103 detected /       56 sextracted
# > Line: 2450  Objects:      103 detected /       59 sextracted
# > Line: 2475  Objects:      106 detected /       59 sextracted
# > Line: 2487  Objects:      107 detected /       60 sextracted
# > Line: 2488  Objects:      107 detected /       60 sextracted
# > Line: 2489  Objects:      107 detected /       60 sextracted
# > Line: 2490  Objects:      107 detected /       60 sextracted
# > Line: 2491  Objects:      107 detected /       60 sextracted
# > Line: 2492  Objects:      107 detected /       60 sextracted
# > Line: 2500  Objects:      107 detected /       61 sextracted
# > Line: 2525  Objects:      107 detected /       63 sextracted
# > Line: 2550  Objects:      109 detected /       64 sextracted
# > Line: 2575  Objects:      109 detected /       65 sextracted
# > Line: 2600  Objects:      111 detected /       65 sextracted
# > Line: 2625  Objects:      114 detected /       67 sextracted
# > Line: 2650  Objects:      115 detected /       68 sextracted
# > Line: 2675  Objects:      115 detected /       69 sextracted
# > Line: 2692  Objects:      117 detected /       70 sextracted
# > Line: 2693  Objects:      117 detected /       70 sextracted
# > Line: 2694  Objects:      117 detected /       70 sextracted
# > Line: 2695  Objects:      117 detected /       70 sextracted
# > Line: 2696  Objects:      117 detected /       70 sextracted
# > Line: 2697  Objects:      117 detected /       70 sextracted
# > Line: 2698  Objects:      118 detected /       70 sextracted
# > Line: 2699  Objects:      118 detected /       70 sextracted
# > Line: 2700  Objects:      118 detected /       70 sextracted
# > Line: 2701  Objects:      118 detected /       70 sextracted
# > Line: 2702  Objects:      118 detected /       70 sextracted
# > Line: 2703  Objects:      118 detected /       70 sextracted
# > Line: 2704  Objects:      118 detected /       70 sextracted
# > Line: 2705  Objects:      118 detected /       70 sextracted
# > Line: 2706  Objects:      118 detected /       70 sextracted
# > Line: 2707  Objects:      118 detected /       70 sextracted
# > Line: 2708  Objects:      119 detected /       70 sextracted
# > Line: 2709  Objects:      119 detected /       70 sextracted
# > Line: 2710  Objects:      119 detected /       70 sextracted
# > Line: 2725  Objects:      119 detected /       72 sextracted
# > Line: 2750  Objects:      121 detected /       72 sextracted
# > Line: 2775  Objects:      124 detected /       73 sextracted
# > Line: 2800  Objects:      125 detected /       73 sextracted
# > Line: 2825  Objects:      129 detected /       73 sextracted
# > Line: 2850  Objects:      131 detected /       73 sextracted
# > Line: 2875  Objects:      134 detected /       74 sextracted
# > Line: 2900  Objects:      135 detected /       76 sextracted
# > Line: 2925  Objects:      136 detected /       76 sextracted
# > Line: 2950  Objects:      138 detected /       79 sextracted
# > Line: 2953  Objects:      138 detected /       80 sextracted
# > Line: 2954  Objects:      138 detected /       80 sextracted
# > Line: 2955  Objects:      138 detected /       80 sextracted
# > Line: 2956  Objects:      138 detected /       80 sextracted
# > Line: 2957  Objects:      138 detected /       80 sextracted
# > Line: 2958  Objects:      138 detected /       80 sextracted
# > Line: 2959  Objects:      138 detected /       80 sextracted
# > Line: 2960  Objects:      138 detected /       80 sextracted
# > Line: 2961  Objects:      138 detected /       80 sextracted
# > Line: 2962  Objects:      138 detected /       80 sextracted
# > Line: 2963  Objects:      138 detected /       80 sextracted
# > Line: 2964  Objects:      139 detected /       80 sextracted
# > Line: 2965  Objects:      139 detected /       80 sextracted
# > Line: 2966  Objects:      139 detected /       80 sextracted
# > Line: 2975  Objects:      139 detected /       81 sextracted
# > Line: 3000  Objects:      141 detected /       82 sextracted
# > Line: 3025  Objects:      142 detected /       82 sextracted
# > Line: 3050  Objects:      142 detected /       82 sextracted
# > Line: 3075  Objects:      143 detected /       84 sextracted
# > Line: 3100  Objects:      145 detected /       85 sextracted
# > Line: 3125  Objects:      146 detected /       88 sextracted
# > Line: 3150  Objects:      147 detected /       88 sextracted
# > Line: 3175  Objects:      148 detected /       89 sextracted
# > Line: 3200  Objects:      149 detected /       89 sextracted
# > Line: 3216  Objects:      150 detected /       90 sextracted
# > Line: 3217  Objects:      150 detected /       90 sextracted
# > Line: 3218  Objects:      151 detected /       90 sextracted
# > Line: 3219  Objects:      151 detected /       90 sextracted
# > Line: 3220  Objects:      151 detected /       90 sextracted
# > Line: 3221  Objects:      151 detected /       90 sextracted
# > Line: 3222  Objects:      151 detected /       90 sextracted
# > Line: 3223  Objects:      151 detected /       90 sextracted
# > Line: 3224  Objects:      151 detected /       90 sextracted
# > Line: 3225  Objects:      151 detected /       90 sextracted
# > Line: 3226  Objects:      151 detected /       90 sextracted
# > Line: 3227  Objects:      151 detected /       90 sextracted
# > Line: 3228  Objects:      151 detected /       90 sextracted
# > Line: 3229  Objects:      151 detected /       90 sextracted
# > Line: 3250  Objects:      153 detected /       93 sextracted
# > Line: 3275  Objects:      154 detected /       93 sextracted
# > Line: 3300  Objects:      156 detected /       96 sextracted
# > Line: 3325  Objects:      160 detected /       98 sextracted
# > Line: 3350  Objects:      162 detected /       98 sextracted
# > Line: 3375  Objects:      162 detected /       99 sextracted
# > Line: 3379  Objects:      162 detected /      100 sextracted
# > Line: 3380  Objects:      162 detected /      100 sextracted
# > Line: 3400  Objects:      162 detected /      102 sextracted
# > Line: 3425  Objects:      163 detected /      103 sextracted
# > Line: 3450  Objects:      164 detected /      104 sextracted
# > Line: 3475  Objects:      165 detected /      106 sextracted
# > Line: 3500  Objects:      165 detected /      107 sextracted
# > Line: 3525  Objects:      166 detected /      107 sextracted
# > Line: 3550  Objects:      166 detected /      108 sextracted
# > Line: 3575  Objects:      167 detected /      109 sextracted
# > Line: 3579  Objects:      167 detected /      110 sextracted
# > Line: 3580  Objects:      167 detected /      110 sextracted
# > Line: 3581  Objects:      167 detected /      110 sextracted
# > Line: 3582  Objects:      167 detected /      110 sextracted
# > Line: 3583  Objects:      167 detected /      110 sextracted
# > Line: 3584  Objects:      167 detected /      110 sextracted
# > Line: 3585  Objects:      167 detected /      110 sextracted
# > Line: 3586  Objects:      167 detected /      110 sextracted
# > Line: 3587  Objects:      168 detected /      110 sextracted
# > Line: 3588  Objects:      168 detected /      110 sextracted
# > Line: 3589  Objects:      168 detected /      110 sextracted
# > Line: 3590  Objects:      168 detected /      110 sextracted
# > Line: 3591  Objects:      168 detected /      110 sextracted
# > Line: 3592  Objects:      168 detected /      110 sextracted
# > Line: 3593  Objects:      168 detected /      110 sextracted
# > Line: 3594  Objects:      168 detected /      110 sextracted
# > Line: 3595  Objects:      168 detected /      110 sextracted
# > Line: 3596  Objects:      168 detected /      110 sextracted
# > Line: 3597  Objects:      168 detected /      110 sextracted
# > Line: 3598  Objects:      168 detected /      110 sextracted
# > Line: 3599  Objects:      169 detected /      110 sextracted
# > Line: 3600  Objects:      169 detected /      110 sextracted
# > Line: 3601  Objects:      169 detected /      110 sextracted
# > Line: 3602  Objects:      169 detected /      110 sextracted
# > Line: 3625  Objects:      171 detected /      114 sextracted
# > Line: 3650  Objects:      171 detected /      115 sextracted
# > Line: 3675  Objects:      173 detected /      116 sextracted
# > Line: 3700  Objects:      175 detected /      117 sextracted
# > Line: 3725  Objects:      175 detected /      119 sextracted
# > Line: 3738  Objects:      175 detected /      120 sextracted
# > Line: 3739  Objects:      175 detected /      120 sextracted
# > Line: 3740  Objects:      175 detected /      120 sextracted
# > Line: 3741  Objects:      175 detected /      120 sextracted
# > Line: 3742  Objects:      175 detected /      120 sextracted
# > Line: 3743  Objects:      175 detected /      120 sextracted
# > Line: 3750  Objects:      175 detected /      121 sextracted
# > Line: 3775  Objects:      175 detected /      123 sextracted
# > Line: 3800  Objects:      175 detected /      124 sextracted
# > Line: 3825  Objects:      177 detected /      129 sextracted
# > Line: 3850  Objects:      178 detected /      129 sextracted
# > Line: 3875  Objects:      178 detected /      129 sextracted
# > Line: 3900  Objects:      178 detected /      129 sextracted
# > Line: 3925  Objects:      179 detected /      129 sextracted
# > Line: 3950  Objects:      179 detected /      129 sextracted
# > Line: 3975  Objects:      180 detected /      129 sextracted
# > Line: 4000  Objects:      180 detected /      129 sextracted
# > Line: 4025  Objects:      181 detected /      129 sextracted
# > Line: 4050  Objects:      182 detected /      129 sextracted
# > Line: 4075  Objects:      183 detected /      129 sextracted
# > Line: 4100  Objects:      183 detected /      129 sextracted
# > Line: 4108  Objects:      183 detected /      130 sextracted
# > Line: 4108  Objects:      183 detected /      140 sextracted
# > Line: 4108  Objects:      183 detected /      150 sextracted
# > Line: 4108  Objects:      183 detected /      160 sextracted
# > Line: 4108  Objects:      183 detected /      170 sextracted
# > Line: 4108  Objects:      183 detected /      180 sextracted
#       Objects: detected 183      / sextracted 183
#
# > Closing files
# >
# > All done (in 2.1 s: 1963.9 lines/s , 87.5 detections/s)

# %%
with fits.open(psfcatalogName) as HDU:
    psfsourceTable = Table(HDU[2].data)

print(psfsourceTable.colnames)
print(psfsourceTable)

cleanPSFSources = psfsourceTable[(psfsourceTable['FLAGS']==0) & (psfsourceTable['FLAGS_MODEL']==0)  & (psfsourceTable['FWHM_WORLD'] < 2) & (psfsourceTable['XMODEL_IMAGE']<3500) & (psfsourceTable['XMODEL_IMAGE']>500) &(psfsourceTable['YMODEL_IMAGE']<3500) &(psfsourceTable['YMODEL_IMAGE']>500)]
# Out:
# ['VIGNET', 'X_IMAGE', 'Y_IMAGE', 'XWIN_IMAGE', 'YWIN_IMAGE', 'ERRAWIN_IMAGE', 'ERRBWIN_IMAGE', 'ALPHAWIN_J2000', 'DELTAWIN_J2000', 'FLUX_RADIUS', 'FWHM_WORLD', 'FLUX_AUTO', 'FLUXERR_AUTO', 'SNR_WIN', 'ELONGATION', 'FLUX_MAX', 'MAG_AUTO', 'MAGERR_AUTO', 'FLAGS', 'BACKGROUND', 'CLASS_STAR', 'FLAGS_MODEL', 'NITER_MODEL', 'XMODEL_IMAGE', 'YMODEL_IMAGE', 'FLUX_POINTSOURCE', 'FLUXERR_POINTSOURCE', 'MAG_POINTSOURCE', 'MAGERR_POINTSOURCE', 'FLUXRATIO_POINTSOURCE', 'FLUXRATIOERR_POINTSOURCE']
#          VIGNET           X_IMAGE  ... FLUXRATIOERR_POINTSOURCE
# ------------------------ --------- ... ------------------------
#  2.1342468 .. -0.8135681 2417.4868 ...                      0.0
# -20.300552 .. -0.6188965  2845.188 ...                      0.0
#   7.0771484 .. 21.869095 2503.1082 ...                      0.0
#    7.557373 .. -5.702667 2417.4932 ...                      0.0
#     8.56395 .. 10.064987 2279.7175 ...                      0.0
# -0.36180115 .. 15.145096 838.68555 ...                      0.0
#  1.2522888 .. -14.694656   930.012 ...                      0.0
#    3.055191 .. 13.893936 1233.9169 ...                      0.0
# -1.2296143 .. 0.44458008  3463.827 ...                      0.0
#  31.847015 .. -23.388725 2133.0015 ...                      0.0
#                      ...       ... ...                      ...
# -11.566895 .. -17.165268  589.1169 ...                      0.0
#  -0.8890686 .. -3.554779 2224.3367 ...                      0.0
#      17.98555 .. 5.16951 3598.2766 ...                      0.0
#  -19.86856 .. 15.1883545 1979.9911 ...                      0.0
#  -3.6453857 .. 13.721619 3054.0044 ...                      0.0
# -14.214478 .. 0.80244446  3658.984 ...                      0.0
# -44.508972 .. -28.928505   328.341 ...                      0.0
#  14.655151 .. -6.4913635 2778.0996 ...                      0.0
# -2.7428284 .. -3.5803375 3483.9922 ...                      0.0
#  10.160629 .. -3.1033783  3585.002 ...                      0.0
# Length = 183 rows

# %%
psfsourceCatCoords = SkyCoord(ra=cleanPSFSources['ALPHAWIN_J2000'], dec=cleanPSFSources['DELTAWIN_J2000'], frame='icrs', unit='degree')
ps1CatCoords = SkyCoord(ra=good_cat_stars['RAJ2000'], dec=good_cat_stars['DEJ2000'], frame='icrs', unit='degree')
photoDistThresh = 0.6
idx_psfimage, idx_psfps1, d2d, d3d = ps1CatCoords.search_around_sky(psfsourceCatCoords, photoDistThresh*u.arcsec)

print(f'Found {len(idx_psfimage)} good cross-matches')
# Out:
# Found 61 good cross-matches

# %%
plt.figure(figsize=(8,8))
plt.scatter(good_cat_stars['gmag'][idx_psfps1], cleanPSFSources['MAG_POINTSOURCE'][idx_psfimage], color='C0', s=10)
plt.xlabel('PS1 magnitude', fontsize=15)
plt.ylabel('Instrumental PSF-fit magnitude', fontsize=15)
plt.show()

# %%
psfoffsets = ma.array(good_cat_stars['gmag'][idx_psfps1] - cleanPSFSources['MAG_POINTSOURCE'][idx_psfimage])
zero_psfmean, zero_psfmed, zero_psfstd = sigma_clipped_stats(psfoffsets)
print('PSF Mean ZP: %.2f\nPSF Median ZP: %.2f\nPSF STD ZP: %.2f'%(zero_psfmean, zero_psfmed, zero_psfstd))
# Out:
# PSF Mean ZP: 24.78
# PSF Median ZP: 24.93
# PSF STD ZP: 0.22

# %%
ra = 210.910674637
dec = 54.3116510708

sn2023ixf_coords = SkyCoord(ra=[ra], dec=[dec], frame='icrs', unit='degree')
idx_sn2023ixf, idx_cleanpsf_sn2023ixf, d2d, d3d = psfsourceCatCoords.search_around_sky(sn2023ixf_coords, photoDistThresh*u.arcsec)
print(f'Found the source at index {idx_cleanpsf_sn2023ixf[0]}')
# Out:
# Found the source at index 64

# %%
sn2023ixf_psfinstmag = cleanPSFSources[idx_cleanpsf_sn2023ixf]['MAG_POINTSOURCE'][0]
sn2023ixf_psfinstmagerr = cleanPSFSources[idx_cleanpsf_sn2023ixf]['MAGERR_POINTSOURCE'][0]

sn2023ixf_psfmag = zero_psfmed + sn2023ixf_psfinstmag
sn2023ixf_psfmagerr = np.sqrt(sn2023ixf_psfinstmagerr**2 + zero_psfstd**2)

print(f'PSF-fit magnitude of SN2023ixf is {sn2023ixf_psfmag} +/- {sn2023ixf_psfmagerr}')
# Out:
# PSF-fit magnitude of SN2023ixf is 11.044462994384766 +/- 0.21575406856984022
