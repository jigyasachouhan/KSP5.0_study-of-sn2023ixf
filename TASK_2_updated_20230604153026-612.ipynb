# %%
import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt
import astropy.units as u
from astropy.io import fits
from astropy.stats import sigma_clipped_stats, sigma_clip
from astropy.table import Table
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS
from astropy.visualization import ZScaleInterval
from astroquery.vizier import Vizier
import subprocess
import os

# %%
def test_dependency(dep, alternate_name=None):
    """
    Test external dependency by trying to run it as a subprocess
    """
    try:
        subprocess.check_output(dep, stderr=subprocess.PIPE, shell=True)
        print("%s is installed properly as %s. OK" % (dep, dep))
        return 1
    except subprocess.CalledProcessError:
        try:
            subprocess.check_output(alternate_name, stderr=subprocess.PIPE, shell=True)
            print("%s is installed properly as %s. OK" % (dep, alternate_name))
            return 1
        except subprocess.CalledProcessError:
            print("===%s/%s IS NOT YET INSTALLED PROPERLY===" % (dep, alternate_name))
            return 0
    
dependencies = [('source-extractor', 'sex'), ('psfex', 'PSFEx')]
i = 0
for dep_name1, dep_name2 in dependencies:
    i += test_dependency(dep_name1, dep_name2)
print("%i out of %i external dependencies installed properly.\n" % (i, len(dependencies)))
if i != len(dependencies):
    print("Please correctly install these programs before continuing by following the instructions in README.md.")
else:
    print("You are ready to continue.")
# Out:
# source-extractor is installed properly as sex. OK
# psfex is installed properly as psfex. OK
# 2 out of 2 external dependencies installed properly.
#
# You are ready to continue.

# %%
os.chdir('/Users/jigyasachouhan/Documents/Krittika/KSP/Task 2/files_TASK_2')
imageName = '20230604153026-612-RA.wcs.proc.fits'

with fits.open(imageName) as HDUList:
    header = HDUList[0].header
    image = HDUList[0].data

zscale = ZScaleInterval().get_limits(image)

plt.figure(figsize=(10,10))
plt.imshow(image, cmap='gray', origin='lower', vmin=zscale[0], vmax=zscale[1])
plt.colorbar()
plt.show()

# %%
w = WCS(header)
(raImage, decImage) = w.all_pix2world(image.shape[0]/2, image.shape[1]/2, 1)
boxsize = 30 # arcminutes
maxmag = 18

catNum = 'II/349'
print(f'\nQuerying Vizier {catNum} around RA {raImage:.4f}, Dec {decImage:.4f} with a radius of {boxsize} arcmin')

try:
    # You can set the filters for the individual columns (magnitude range, number of detections) inside the Vizier query
    v = Vizier(columns=['*'], column_filters={"gmag":f"<{maxmag}", "Nd":">6", "e_gmag":f"<{1.086/3}"}, row_limit=-1)
    Q = v.query_region(SkyCoord(ra=raImage, dec=decImage, unit=(u.deg, u.deg)), radius=str(boxsize)+'m', catalog=catNum, cache=False)
    print(Q[0])
except:
    print('I cannnot reach the Vizier database. Is the internet working?')
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60099.646141 from DATE-OBS'. [astropy.wcs.wcs]
# Querying Vizier II/349 around RA 211.1314, Dec 54.3099 with a radius of 30 arcmin
#    RAJ2000       DEJ2000          objID        ...  yKmag  e_yKmag yFlags
#      deg           deg                         ...   mag     mag
# ------------- ------------- ------------------ ... ------- ------- ------
# 210.663724090  53.919290610 172702106637313866 ... 16.4559  0.0164 115000
# 210.663539540  53.892741500 172672106635471999 ... 16.3082  0.0166 115000
# 210.604486980  53.926405740 172712106044792397 ... 16.4376  0.0142 115000
# 210.625757450  53.949266840 172732106257949830 ... 13.8435  0.0035 115000
# 210.447712130  54.046944570 172852104477077040 ... 14.0260  0.0031 115000
# 210.394009680  54.069378840 172882103939893987 ... 15.2874  0.0041 115000
# 210.377594030  54.093628720 172912103775753110 ... 13.8098  0.0052 115000
# 211.551848240  53.914855810 172692115517798643 ... 13.7540  0.0019 115000
# 211.670892740  53.925284680 172712116707871056 ... 13.8763  0.0090 115000
#           ...           ...                ... ...     ...     ...    ...
# 211.389644660  54.709108870 173652113897101556 ... 14.3704  0.0030 115000
# 211.383188040  54.721429910 173662113832166340 ... 14.7420  0.0198 115000
# 211.447903520  54.683426060 173622114479190746 ... 16.5702  0.0106 115000
# 211.397292700  54.731710700 173672113972788684 ... 16.2727  0.0165 115000
# 211.450513470  54.748214270 173692114504318428 ... 14.5338  0.0032 115000
# 211.418571590  54.758291300 173712114185810617 ... 14.8753  0.0026 115000
# 211.325299540  54.736859470 173682113252044964 ... 12.9410  0.0051 115000
# 211.341417080  54.752394860 173702113414513525 ... 14.2975  0.0106 115000
# 211.320961040  54.795940480 173752113209525801 ... 16.4233  0.0113 115000
# 211.312292400  54.789897370 173742113123078539 ... 14.0685  0.0011 115000
# Length = 637 rows

# %%
Q[0].meta['desc'] = Q[0].meta.pop('description')
Q[0].write('/Users/jigyasachouhan/Documents/Krittika/KSP/Task 2/files_TASK_2/ps1Catalog.fits', format='fits', overwrite=True)

# %%
ps1_imCoords = w.all_world2pix(Q[0]['RAJ2000'], Q[0]['DEJ2000'], 1)
good_cat_stars = Q[0][np.where((ps1_imCoords[0] > 500) & (ps1_imCoords[0] < 3500) & (ps1_imCoords[1] > 500) & (ps1_imCoords[1] < 3500))]
ps1_imCoords = w.all_world2pix(good_cat_stars['RAJ2000'],good_cat_stars['DEJ2000'], 1)

fig = plt.figure(figsize=(10,10))
ax = fig.gca()
plt.imshow(image, cmap='gray', vmin=zscale[0], vmax=zscale[1])
circles = [plt.Circle((ps1_imCoords[0][i], ps1_imCoords[1][i]), radius = 10, edgecolor='C1', facecolor='None') for i in range(len(ps1_imCoords[0]))]
for c in circles:
    ax.add_artist(c)
    
plt.show()

# %%
configFile = 'photomCat.sex'
catalogName = imageName + '.cat'
paramName = 'photomCat.param'
try:
    command = f'sex -c {configFile} {imageName} -CATALOG_NAME {catalogName} -PARAMETERS_NAME {paramName}'
    print(f'Executing command: {command}')
    rval = subprocess.run(command.split(), check=True)
except subprocess.CalledProcessError as err:
    print(f'Could not run sextractor with exit error {err}')
# Out:
# Executing command: sex -c photomCat.sex 20230604153026-612-RA.wcs.proc.fits -CATALOG_NAME 20230604153026-612-RA.wcs.proc.fits.cat -PARAMETERS_NAME photomCat.param
# >
# ----- SExtractor 2.28.0 started on 2024-07-01 at 12:08:45 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing catalog
# > Looking for 20230604153026-612-RA.wcs.proc.fits
# ----- Measuring from: 20230604153026-612-RA.wcs.proc.fits
#       "SN2023ixf" / no ext. header / 4096x4108 / 64 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line: 1024
# > Setting up background map at line: 2048
# > Setting up background map at line: 3072
# > Setting up background map at line: 4096
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 71.8685    RMS: 14.1167    / Threshold: 141.167
# > Scanning image
# > Line:   25  Objects:        1 detected /        0 sextracted
# > Line:   50  Objects:        2 detected /        0 sextracted
# > Line:   75  Objects:        4 detected /        0 sextracted
# > Line:  100  Objects:        5 detected /        0 sextracted
# > Line:  125  Objects:        7 detected /        0 sextracted
# > Line:  150  Objects:        8 detected /        0 sextracted
# > Line:  175  Objects:        8 detected /        0 sextracted
# > Line:  200  Objects:        8 detected /        0 sextracted
# > Line:  225  Objects:        8 detected /        0 sextracted
# > Line:  250  Objects:        9 detected /        0 sextracted
# > Line:  275  Objects:        9 detected /        0 sextracted
# > Line:  300  Objects:       10 detected /        0 sextracted
# > Line:  325  Objects:       13 detected /        0 sextracted
# > Line:  350  Objects:       14 detected /        0 sextracted
# > Line:  375  Objects:       15 detected /        0 sextracted
# > Line:  400  Objects:       16 detected /        0 sextracted
# > Line:  425  Objects:       18 detected /        0 sextracted
# > Line:  450  Objects:       18 detected /        0 sextracted
# > Line:  475  Objects:       18 detected /        0 sextracted
# > Line:  500  Objects:       19 detected /        0 sextracted
# > Line:  525  Objects:       20 detected /        0 sextracted
# > Line:  550  Objects:       23 detected /        0 sextracted
# > Line:  575  Objects:       24 detected /        0 sextracted
# > Line:  600  Objects:       25 detected /        0 sextracted
# > Line:  625  Objects:       27 detected /        0 sextracted
# > Line:  650  Objects:       28 detected /        0 sextracted
# > Line:  675  Objects:       29 detected /        0 sextracted
# > Line:  700  Objects:       30 detected /        0 sextracted
# > Line:  725  Objects:       30 detected /        0 sextracted
# > Line:  750  Objects:       32 detected /        0 sextracted
# > Line:  775  Objects:       32 detected /        0 sextracted
# > Line:  800  Objects:       34 detected /        0 sextracted
# > Line:  825  Objects:       36 detected /        0 sextracted
# > Line:  850  Objects:       38 detected /        0 sextracted
# > Line:  875  Objects:       40 detected /        0 sextracted
# > Line:  900  Objects:       40 detected /        0 sextracted
# > Line:  925  Objects:       43 detected /        0 sextracted
# > Line:  950  Objects:       43 detected /        0 sextracted
# > Line:  975  Objects:       43 detected /        0 sextracted
# > Line: 1000  Objects:       43 detected /        0 sextracted
# > Line: 1023  Objects:       43 detected /        0 sextracted
# > Line: 1025  Objects:       43 detected /        1 sextracted
# > Line: 1050  Objects:       45 detected /        2 sextracted
# > Line: 1075  Objects:       46 detected /        4 sextracted
# > Line: 1100  Objects:       47 detected /        5 sextracted
# > Line: 1125  Objects:       50 detected /        7 sextracted
# > Line: 1150  Objects:       51 detected /        7 sextracted
# > Line: 1175  Objects:       53 detected /        8 sextracted
# > Line: 1200  Objects:       55 detected /        8 sextracted
# > Line: 1225  Objects:       56 detected /        8 sextracted
# > Line: 1250  Objects:       58 detected /        9 sextracted
# > Line: 1275  Objects:       59 detected /        9 sextracted
# > Line: 1300  Objects:       61 detected /       10 sextracted
# > Line: 1325  Objects:       64 detected /       13 sextracted
# > Line: 1350  Objects:       64 detected /       14 sextracted
# > Line: 1375  Objects:       66 detected /       15 sextracted
# > Line: 1400  Objects:       68 detected /       16 sextracted
# > Line: 1425  Objects:       70 detected /       18 sextracted
# > Line: 1450  Objects:       71 detected /       18 sextracted
# > Line: 1475  Objects:       72 detected /       18 sextracted
# > Line: 1500  Objects:       73 detected /       18 sextracted
# > Line: 1525  Objects:       76 detected /       20 sextracted
# > Line: 1550  Objects:       77 detected /       23 sextracted
# > Line: 1575  Objects:       78 detected /       24 sextracted
# > Line: 1600  Objects:       78 detected /       25 sextracted
# > Line: 1625  Objects:       78 detected /       28 sextracted
# > Line: 1650  Objects:       78 detected /       29 sextracted
# > Line: 1675  Objects:       80 detected /       29 sextracted
# > Line: 1700  Objects:       82 detected /       29 sextracted
# > Line: 1725  Objects:       82 detected /       30 sextracted
# > Line: 1750  Objects:       82 detected /       32 sextracted
# > Line: 1775  Objects:       86 detected /       32 sextracted
# > Line: 1800  Objects:       86 detected /       33 sextracted
# > Line: 1825  Objects:       86 detected /       37 sextracted
# > Line: 1850  Objects:       91 detected /       40 sextracted
# > Line: 1875  Objects:       93 detected /       40 sextracted
# > Line: 1900  Objects:       95 detected /       41 sextracted
# > Line: 1925  Objects:       97 detected /       43 sextracted
# > Line: 1950  Objects:      100 detected /       43 sextracted
# > Line: 1975  Objects:      101 detected /       43 sextracted
# > Line: 2000  Objects:      102 detected /       43 sextracted
# > Line: 2025  Objects:      102 detected /       43 sextracted
# > Line: 2050  Objects:      104 detected /       44 sextracted
# > Line: 2075  Objects:      105 detected /       46 sextracted
# > Line: 2100  Objects:      106 detected /       47 sextracted
# > Line: 2125  Objects:      108 detected /       49 sextracted
# > Line: 2150  Objects:      108 detected /       51 sextracted
# > Line: 2175  Objects:      108 detected /       53 sextracted
# > Line: 2200  Objects:      109 detected /       56 sextracted
# > Line: 2225  Objects:      109 detected /       56 sextracted
# > Line: 2250  Objects:      110 detected /       57 sextracted
# > Line: 2275  Objects:      111 detected /       60 sextracted
# > Line: 2300  Objects:      111 detected /       61 sextracted
# > Line: 2325  Objects:      111 detected /       64 sextracted
# > Line: 2350  Objects:      114 detected /       66 sextracted
# > Line: 2375  Objects:      116 detected /       67 sextracted
# > Line: 2400  Objects:      118 detected /       67 sextracted
# > Line: 2425  Objects:      121 detected /       70 sextracted
# > Line: 2450  Objects:      123 detected /       71 sextracted
# > Line: 2475  Objects:      124 detected /       72 sextracted
# > Line: 2500  Objects:      124 detected /       73 sextracted
# > Line: 2525  Objects:      127 detected /       75 sextracted
# > Line: 2550  Objects:      128 detected /       77 sextracted
# > Line: 2575  Objects:      129 detected /       78 sextracted
# > Line: 2600  Objects:      133 detected /       78 sextracted
# > Line: 2625  Objects:      134 detected /       78 sextracted
# > Line: 2650  Objects:      136 detected /       79 sextracted
# > Line: 2675  Objects:      137 detected /       81 sextracted
# > Line: 2700  Objects:      139 detected /       82 sextracted
# > Line: 2725  Objects:      142 detected /       82 sextracted
# > Line: 2750  Objects:      145 detected /       82 sextracted
# > Line: 2775  Objects:      147 detected /       86 sextracted
# > Line: 2800  Objects:      148 detected /       86 sextracted
# > Line: 2825  Objects:      150 detected /       87 sextracted
# > Line: 2850  Objects:      152 detected /       90 sextracted
# > Line: 2875  Objects:      154 detected /       93 sextracted
# > Line: 2900  Objects:      155 detected /       95 sextracted
# > Line: 2925  Objects:      158 detected /       96 sextracted
# > Line: 2950  Objects:      162 detected /      100 sextracted
# > Line: 2975  Objects:      165 detected /      101 sextracted
# > Line: 3000  Objects:      168 detected /      102 sextracted
# > Line: 3025  Objects:      170 detected /      102 sextracted
# > Line: 3050  Objects:      173 detected /      104 sextracted
# > Line: 3075  Objects:      175 detected /      106 sextracted
# > Line: 3100  Objects:      177 detected /      106 sextracted
# > Line: 3125  Objects:      177 detected /      108 sextracted
# > Line: 3150  Objects:      178 detected /      108 sextracted
# > Line: 3175  Objects:      179 detected /      108 sextracted
# > Line: 3200  Objects:      181 detected /      109 sextracted
# > Line: 3225  Objects:      181 detected /      109 sextracted
# > Line: 3250  Objects:      183 detected /      110 sextracted
# > Line: 3275  Objects:      186 detected /      110 sextracted
# > Line: 3300  Objects:      188 detected /      111 sextracted
# > Line: 3325  Objects:      190 detected /      112 sextracted
# > Line: 3350  Objects:      191 detected /      115 sextracted
# > Line: 3375  Objects:      192 detected /      115 sextracted
# > Line: 3400  Objects:      193 detected /      117 sextracted
# > Line: 3425  Objects:      194 detected /      121 sextracted
# > Line: 3450  Objects:      197 detected /      122 sextracted
# > Line: 3475  Objects:      198 detected /      123 sextracted
# > Line: 3500  Objects:      201 detected /      123 sextracted
# > Line: 3525  Objects:      204 detected /      126 sextracted
# > Line: 3550  Objects:      206 detected /      127 sextracted
# > Line: 3575  Objects:      206 detected /      129 sextracted
# > Line: 3600  Objects:      206 detected /      133 sextracted
# > Line: 3625  Objects:      208 detected /      133 sextracted
# > Line: 3650  Objects:      208 detected /      135 sextracted
# > Line: 3675  Objects:      211 detected /      137 sextracted
# > Line: 3700  Objects:      212 detected /      138 sextracted
# > Line: 3725  Objects:      212 detected /      141 sextracted
# > Line: 3750  Objects:      212 detected /      144 sextracted
# > Line: 3775  Objects:      212 detected /      145 sextracted
# > Line: 3800  Objects:      212 detected /      146 sextracted
# > Line: 3825  Objects:      213 detected /      149 sextracted
# > Line: 3850  Objects:      214 detected /      149 sextracted
# > Line: 3875  Objects:      217 detected /      149 sextracted
# > Line: 3900  Objects:      217 detected /      149 sextracted
# > Line: 3925  Objects:      217 detected /      149 sextracted
# > Line: 3950  Objects:      218 detected /      149 sextracted
# > Line: 3975  Objects:      220 detected /      149 sextracted
# > Line: 4000  Objects:      221 detected /      149 sextracted
# > Line: 4025  Objects:      221 detected /      149 sextracted
# > Line: 4050  Objects:      221 detected /      149 sextracted
# > Line: 4075  Objects:      222 detected /      149 sextracted
# > Line: 4100  Objects:      222 detected /      149 sextracted
#       Objects: detected 222      / sextracted 221
#
# > Closing files
# >
# > All done (in 0.6 s: 7376.7 lines/s , 396.8 detections/s)

# %%
with fits.open(catalogName) as HDU:
    print(HDU.info())
    sourceTable = Table(HDU[2].data)

print(sourceTable.colnames)
print(sourceTable)

cleanSources = sourceTable[(sourceTable['FLAGS']==0) & (sourceTable['FWHM_WORLD'] < 2) & (sourceTable['XWIN_IMAGE']<3500) & (sourceTable['XWIN_IMAGE']>500) & (sourceTable['YWIN_IMAGE']<3500) & (sourceTable['YWIN_IMAGE']>500)]
# Out:
# Filename: 20230604153026-612-RA.wcs.proc.fits.cat
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  LDAC_IMHEAD    1 BinTableHDU     12   1R x 1C   [18880A]
#   2  LDAC_OBJECTS    1 BinTableHDU    106   221R x 25C   [729E, 1E, 1E, 1D, 1D, 1E, 1E, 1D, 1D, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1I, 1E, 1E, 10E, 10E, 10E, 10E]
# None
# ['VIGNET', 'X_IMAGE', 'Y_IMAGE', 'XWIN_IMAGE', 'YWIN_IMAGE', 'ERRAWIN_IMAGE', 'ERRBWIN_IMAGE', 'ALPHAWIN_J2000', 'DELTAWIN_J2000', 'FLUX_RADIUS', 'FWHM_WORLD', 'FLUX_AUTO', 'FLUXERR_AUTO', 'SNR_WIN', 'ELONGATION', 'FLUX_MAX', 'MAG_AUTO', 'MAGERR_AUTO', 'FLAGS', 'BACKGROUND', 'CLASS_STAR', 'FLUX_APER', 'FLUXERR_APER', 'MAG_APER', 'MAGERR_APER']
#           VIGNET           X_IMAGE  ...          MAGERR_APER
# ------------------------- --------- ... ------------------------------
#   -16.929665 .. 22.306328  2417.488 ...  0.00039380166 .. 0.0003993951
#     2.2637634 .. 6.153885  2805.876 ...     0.010518165 .. 0.015299038
#  -11.066479 .. -29.247993 2071.0793 ...      0.009878367 .. 0.03087282
#  -22.728722 .. -14.198463 1415.7877 ...      0.02444069 .. 0.034629323
#   -29.660149 .. 5.9923935 1260.1746 ...   0.0037322333 .. 0.0050009927
#  -17.756145 .. -2.4073105 1260.0012 ...     0.025834978 .. 0.034540273
#    -1.2082825 .. 9.906868 1828.6741 ...     0.023713883 .. 0.031767067
#   -3.8538055 .. -9.010723 2417.4932 ...  0.0004076395 .. 0.00041097778
#    27.334137 .. 22.048744 1229.0016 ...      0.045823157 .. 0.12479756
#   14.407951 .. -6.4341125 2688.4873 ...     0.016230332 .. 0.022637947
#                       ...       ... ...                            ...
#    8.364044 .. -17.003418 2829.0085 ...     0.021631937 .. 0.041858625
#  -0.31998444 .. 18.305046  681.6299 ... 0.00010473693 .. 0.00016732563
#      16.95922 .. 9.220581 2965.3499 ...     0.019263102 .. 0.034575284
#   -11.343643 .. 4.8153305  294.9947 ...      0.019250706 .. 0.03295198
#   -5.4634094 .. 7.4479904 254.99849 ...      0.00249986 .. 0.003969114
#     11.84964 .. -17.66615 2926.0173 ...     0.030870209 .. 0.056299828
#    -16.94394 .. 17.692505 1319.9159 ...      0.024737757 .. 0.07576298
#   2.4160004 .. -4.1684647 2424.6853 ...   0.0010846206 .. 0.0019111407
# -7.8391876 .. -13.9818535 1209.9054 ...     0.012036248 .. 0.020844398
#    4.0595856 .. 19.030876 1936.0024 ...     0.011635381 .. 0.039002094
# Length = 221 rows

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
plt.imshow(image, cmap='gray', vmin=zscale[0], vmax=zscale[1])
circles = [plt.Circle((source['XWIN_IMAGE'], source['YWIN_IMAGE']), radius = 10, edgecolor='C1', facecolor='None') for source in cleanSources]
for c in circles:
    ax.add_artist(c)
plt.show()

# %%
psfConfigFile = 'psfex_conf.psfex'

try:
    command = f'psfex -c {psfConfigFile} {catalogName}'
    print(f'Executing command: {command}')
    rval = subprocess.run(command.split(), check=True)
except subprocess.CalledProcessError as err:
    print(f'Could not run psfex with exit error {err}')
# Out:
# Executing command: psfex -c psfex_conf.psfex 20230604153026-612-RA.wcs.proc.fits.cat
# > WARNING: This executable has been compiled using a version of the ATLAS library without support for multithreading. Performance will be degraded.

# %%
psfModelHDU = fits.open('moffat_' + imageName + '.fits')[0]
psfModelData = psfModelHDU.data
mean, median, std = sigma_clipped_stats(psfModelData)

plt.figure(figsize=(6,6))
plt.imshow(psfModelData, vmin=0, vmax=median+20*std, origin='lower')
plt.show()

# %%
psfName = imageName + '.psf'
psfcatalogName = imageName+'.psf.cat'
psfparamName = 'photomPSF.param' # This is a new set of parameters to be obtained from SExtractor, including PSF-fit magnitudes
try:
    # We are supplying SExtactor with the PSF model with the PSF_NAME option
    command = f'sex -c {configFile} {imageName} -CATALOG_NAME {psfcatalogName} -PSF_NAME {psfName} -PARAMETERS_NAME {psfparamName}'
    print(f"Executing command: {command}")
    rval = subprocess.run(command.split(), check=True)
except subprocess.CalledProcessError as err:
    print(f'Could not run sextractor with exit error {err}')
# Out:
# Executing command: sex -c photomCat.sex 20230604153026-612-RA.wcs.proc.fits -CATALOG_NAME 20230604153026-612-RA.wcs.proc.fits.psf.cat -PSF_NAME 20230604153026-612-RA.wcs.proc.fits.psf -PARAMETERS_NAME photomPSF.param
# >
# ----- SExtractor 2.28.0 started on 2024-07-01 at 12:08:48 with 1 thread
#
# > Setting catalog parameters
# > Reading PSF information
# > Preparing profile models
# Fitting model: point source
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing catalog
# > Looking for 20230604153026-612-RA.wcs.proc.fits
# ----- Measuring from: 20230604153026-612-RA.wcs.proc.fits
#       "SN2023ixf" / no ext. header / 4096x4108 / 64 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line: 1024
# > Setting up background map at line: 2048
# > Setting up background map at line: 3072
# > Setting up background map at line: 4096
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 71.8685    RMS: 14.1167    / Threshold: 141.167
# > Scanning image
# > Line:    1  Objects:        0 detected /        0 sextracted
# > Line:    2  Objects:        0 detected /        0 sextracted
# > Line:    3  Objects:        0 detected /        0 sextracted
# > Line:    4  Objects:        0 detected /        0 sextracted
# > Line:    5  Objects:        0 detected /        0 sextracted
# > Line:    6  Objects:        0 detected /        0 sextracted
# > Line:    7  Objects:        0 detected /        0 sextracted
# > Line:    8  Objects:        0 detected /        0 sextracted
# > Line:    9  Objects:        0 detected /        0 sextracted
# > Line:   10  Objects:        0 detected /        0 sextracted
# > Line:   11  Objects:        0 detected /        0 sextracted
# > Line:   12  Objects:        0 detected /        0 sextracted
# > Line:   13  Objects:        0 detected /        0 sextracted
# > Line:   14  Objects:        0 detected /        0 sextracted
# > Line:   15  Objects:        0 detected /        0 sextracted
# > Line:   16  Objects:        0 detected /        0 sextracted
# > Line:   17  Objects:        1 detected /        0 sextracted
# > Line:   18  Objects:        1 detected /        0 sextracted
# > Line:   19  Objects:        1 detected /        0 sextracted
# > Line:   20  Objects:        1 detected /        0 sextracted
# > Line:   21  Objects:        1 detected /        0 sextracted
# > Line:   22  Objects:        1 detected /        0 sextracted
# > Line:   23  Objects:        1 detected /        0 sextracted
# > Line:   24  Objects:        1 detected /        0 sextracted
# > Line:   25  Objects:        1 detected /        0 sextracted
# > Line:   26  Objects:        1 detected /        0 sextracted
# > Line:   27  Objects:        1 detected /        0 sextracted
# > Line:   28  Objects:        1 detected /        0 sextracted
# > Line:   29  Objects:        2 detected /        0 sextracted
# > Line:   30  Objects:        2 detected /        0 sextracted
# > Line:   31  Objects:        2 detected /        0 sextracted
# > Line:   32  Objects:        2 detected /        0 sextracted
# > Line:   33  Objects:        2 detected /        0 sextracted
# > Line:   34  Objects:        2 detected /        0 sextracted
# > Line:   35  Objects:        2 detected /        0 sextracted
# > Line:   36  Objects:        2 detected /        0 sextracted
# > Line:   37  Objects:        2 detected /        0 sextracted
# > Line:   38  Objects:        2 detected /        0 sextracted
# > Line:   39  Objects:        2 detected /        0 sextracted
# > Line:   40  Objects:        2 detected /        0 sextracted
# > Line:   41  Objects:        2 detected /        0 sextracted
# > Line:   42  Objects:        2 detected /        0 sextracted
# > Line:   43  Objects:        2 detected /        0 sextracted
# > Line:   44  Objects:        2 detected /        0 sextracted
# > Line:   45  Objects:        2 detected /        0 sextracted
# > Line:   46  Objects:        2 detected /        0 sextracted
# > Line:   47  Objects:        2 detected /        0 sextracted
# > Line:   48  Objects:        2 detected /        0 sextracted
# > Line:   49  Objects:        2 detected /        0 sextracted
# > Line:   50  Objects:        2 detected /        0 sextracted
# > Line:   51  Objects:        2 detected /        0 sextracted
# > Line:   52  Objects:        2 detected /        0 sextracted
# > Line:   53  Objects:        2 detected /        0 sextracted
# > Line:   54  Objects:        2 detected /        0 sextracted
# > Line:   55  Objects:        2 detected /        0 sextracted
# > Line:   56  Objects:        2 detected /        0 sextracted
# > Line:   57  Objects:        2 detected /        0 sextracted
# > Line:   58  Objects:        2 detected /        0 sextracted
# > Line:   59  Objects:        2 detected /        0 sextracted
# > Line:   60  Objects:        2 detected /        0 sextracted
# > Line:   61  Objects:        2 detected /        0 sextracted
# > Line:   62  Objects:        3 detected /        0 sextracted
# > Line:   63  Objects:        3 detected /        0 sextracted
# > Line:   64  Objects:        3 detected /        0 sextracted
# > Line:   65  Objects:        3 detected /        0 sextracted
# > Line:   66  Objects:        3 detected /        0 sextracted
# > Line:   67  Objects:        3 detected /        0 sextracted
# > Line:   68  Objects:        4 detected /        0 sextracted
# > Line:   69  Objects:        4 detected /        0 sextracted
# > Line:   70  Objects:        4 detected /        0 sextracted
# > Line:   71  Objects:        4 detected /        0 sextracted
# > Line:   72  Objects:        4 detected /        0 sextracted
# > Line:   73  Objects:        4 detected /        0 sextracted
# > Line:   74  Objects:        4 detected /        0 sextracted
# > Line:   75  Objects:        4 detected /        0 sextracted
# > Line:   76  Objects:        4 detected /        0 sextracted
# > Line:   77  Objects:        4 detected /        0 sextracted
# > Line:   78  Objects:        4 detected /        0 sextracted
# > Line:   79  Objects:        4 detected /        0 sextracted
# > Line:   80  Objects:        4 detected /        0 sextracted
# > Line:   81  Objects:        4 detected /        0 sextracted
# > Line:   82  Objects:        4 detected /        0 sextracted
# > Line:   83  Objects:        4 detected /        0 sextracted
# > Line:   84  Objects:        4 detected /        0 sextracted
# > Line:   85  Objects:        4 detected /        0 sextracted
# > Line:   86  Objects:        4 detected /        0 sextracted
# > Line:   87  Objects:        4 detected /        0 sextracted
# > Line:   88  Objects:        4 detected /        0 sextracted
# > Line:   89  Objects:        4 detected /        0 sextracted
# > Line:   90  Objects:        4 detected /        0 sextracted
# > Line:   91  Objects:        4 detected /        0 sextracted
# > Line:   92  Objects:        4 detected /        0 sextracted
# > Line:   93  Objects:        4 detected /        0 sextracted
# > Line:   94  Objects:        4 detected /        0 sextracted
# > Line:   95  Objects:        5 detected /        0 sextracted
# > Line:   96  Objects:        5 detected /        0 sextracted
# > Line:   97  Objects:        5 detected /        0 sextracted
# > Line:   98  Objects:        5 detected /        0 sextracted
# > Line:   99  Objects:        5 detected /        0 sextracted
# > Line:  100  Objects:        5 detected /        0 sextracted
# > Line:  101  Objects:        5 detected /        0 sextracted
# > Line:  102  Objects:        5 detected /        0 sextracted
# > Line:  103  Objects:        5 detected /        0 sextracted
# > Line:  104  Objects:        5 detected /        0 sextracted
# > Line:  105  Objects:        5 detected /        0 sextracted
# > Line:  106  Objects:        5 detected /        0 sextracted
# > Line:  107  Objects:        5 detected /        0 sextracted
# > Line:  108  Objects:        5 detected /        0 sextracted
# > Line:  109  Objects:        5 detected /        0 sextracted
# > Line:  110  Objects:        6 detected /        0 sextracted
# > Line:  111  Objects:        6 detected /        0 sextracted
# > Line:  112  Objects:        6 detected /        0 sextracted
# > Line:  113  Objects:        6 detected /        0 sextracted
# > Line:  114  Objects:        6 detected /        0 sextracted
# > Line:  115  Objects:        6 detected /        0 sextracted
# > Line:  116  Objects:        6 detected /        0 sextracted
# > Line:  117  Objects:        6 detected /        0 sextracted
# > Line:  118  Objects:        6 detected /        0 sextracted
# > Line:  119  Objects:        6 detected /        0 sextracted
# > Line:  120  Objects:        6 detected /        0 sextracted
# > Line:  121  Objects:        7 detected /        0 sextracted
# > Line:  122  Objects:        7 detected /        0 sextracted
# > Line:  123  Objects:        7 detected /        0 sextracted
# > Line:  124  Objects:        7 detected /        0 sextracted
# > Line:  125  Objects:        7 detected /        0 sextracted
# > Line:  126  Objects:        7 detected /        0 sextracted
# > Line:  127  Objects:        7 detected /        0 sextracted
# > Line:  128  Objects:        7 detected /        0 sextracted
# > Line:  129  Objects:        7 detected /        0 sextracted
# > Line:  130  Objects:        7 detected /        0 sextracted
# > Line:  131  Objects:        7 detected /        0 sextracted
# > Line:  132  Objects:        7 detected /        0 sextracted
# > Line:  133  Objects:        7 detected /        0 sextracted
# > Line:  134  Objects:        7 detected /        0 sextracted
# > Line:  135  Objects:        7 detected /        0 sextracted
# > Line:  136  Objects:        7 detected /        0 sextracted
# > Line:  137  Objects:        7 detected /        0 sextracted
# > Line:  138  Objects:        7 detected /        0 sextracted
# > Line:  139  Objects:        7 detected /        0 sextracted
# > Line:  140  Objects:        7 detected /        0 sextracted
# > Line:  141  Objects:        7 detected /        0 sextracted
# > Line:  142  Objects:        7 detected /        0 sextracted
# > Line:  143  Objects:        7 detected /        0 sextracted
# > Line:  144  Objects:        7 detected /        0 sextracted
# > Line:  145  Objects:        8 detected /        0 sextracted
# > Line:  146  Objects:        8 detected /        0 sextracted
# > Line:  147  Objects:        8 detected /        0 sextracted
# > Line:  148  Objects:        8 detected /        0 sextracted
# > Line:  149  Objects:        8 detected /        0 sextracted
# > Line:  150  Objects:        8 detected /        0 sextracted
# > Line:  151  Objects:        8 detected /        0 sextracted
# > Line:  152  Objects:        8 detected /        0 sextracted
# > Line:  153  Objects:        8 detected /        0 sextracted
# > Line:  154  Objects:        8 detected /        0 sextracted
# > Line:  155  Objects:        8 detected /        0 sextracted
# > Line:  156  Objects:        8 detected /        0 sextracted
# > Line:  157  Objects:        8 detected /        0 sextracted
# > Line:  158  Objects:        8 detected /        0 sextracted
# > Line:  159  Objects:        8 detected /        0 sextracted
# > Line:  160  Objects:        8 detected /        0 sextracted
# > Line:  161  Objects:        8 detected /        0 sextracted
# > Line:  162  Objects:        8 detected /        0 sextracted
# > Line:  163  Objects:        8 detected /        0 sextracted
# > Line:  164  Objects:        8 detected /        0 sextracted
# > Line:  165  Objects:        8 detected /        0 sextracted
# > Line:  166  Objects:        8 detected /        0 sextracted
# > Line:  167  Objects:        8 detected /        0 sextracted
# > Line:  168  Objects:        8 detected /        0 sextracted
# > Line:  169  Objects:        8 detected /        0 sextracted
# > Line:  170  Objects:        8 detected /        0 sextracted
# > Line:  171  Objects:        8 detected /        0 sextracted
# > Line:  172  Objects:        8 detected /        0 sextracted
# > Line:  173  Objects:        8 detected /        0 sextracted
# > Line:  174  Objects:        8 detected /        0 sextracted
# > Line:  175  Objects:        8 detected /        0 sextracted
# > Line:  176  Objects:        8 detected /        0 sextracted
# > Line:  177  Objects:        8 detected /        0 sextracted
# > Line:  178  Objects:        8 detected /        0 sextracted
# > Line:  179  Objects:        8 detected /        0 sextracted
# > Line:  180  Objects:        8 detected /        0 sextracted
# > Line:  181  Objects:        8 detected /        0 sextracted
# > Line:  182  Objects:        8 detected /        0 sextracted
# > Line:  183  Objects:        8 detected /        0 sextracted
# > Line:  184  Objects:        8 detected /        0 sextracted
# > Line:  185  Objects:        8 detected /        0 sextracted
# > Line:  186  Objects:        8 detected /        0 sextracted
# > Line:  187  Objects:        8 detected /        0 sextracted
# > Line:  188  Objects:        8 detected /        0 sextracted
# > Line:  189  Objects:        8 detected /        0 sextracted
# > Line:  190  Objects:        8 detected /        0 sextracted
# > Line:  191  Objects:        8 detected /        0 sextracted
# > Line:  192  Objects:        8 detected /        0 sextracted
# > Line:  193  Objects:        8 detected /        0 sextracted
# > Line:  194  Objects:        8 detected /        0 sextracted
# > Line:  195  Objects:        8 detected /        0 sextracted
# > Line:  196  Objects:        8 detected /        0 sextracted
# > Line:  197  Objects:        8 detected /        0 sextracted
# > Line:  198  Objects:        8 detected /        0 sextracted
# > Line:  199  Objects:        8 detected /        0 sextracted
# > Line:  200  Objects:        8 detected /        0 sextracted
# > Line:  201  Objects:        8 detected /        0 sextracted
# > Line:  202  Objects:        8 detected /        0 sextracted
# > Line:  203  Objects:        8 detected /        0 sextracted
# > Line:  204  Objects:        8 detected /        0 sextracted
# > Line:  205  Objects:        8 detected /        0 sextracted
# > Line:  206  Objects:        8 detected /        0 sextracted
# > Line:  207  Objects:        8 detected /        0 sextracted
# > Line:  208  Objects:        8 detected /        0 sextracted
# > Line:  209  Objects:        8 detected /        0 sextracted
# > Line:  210  Objects:        8 detected /        0 sextracted
# > Line:  211  Objects:        8 detected /        0 sextracted
# > Line:  212  Objects:        8 detected /        0 sextracted
# > Line:  213  Objects:        8 detected /        0 sextracted
# > Line:  214  Objects:        8 detected /        0 sextracted
# > Line:  215  Objects:        8 detected /        0 sextracted
# > Line:  216  Objects:        8 detected /        0 sextracted
# > Line:  217  Objects:        8 detected /        0 sextracted
# > Line:  218  Objects:        8 detected /        0 sextracted
# > Line:  219  Objects:        8 detected /        0 sextracted
# > Line:  220  Objects:        8 detected /        0 sextracted
# > Line:  221  Objects:        8 detected /        0 sextracted
# > Line:  222  Objects:        8 detected /        0 sextracted
# > Line:  223  Objects:        8 detected /        0 sextracted
# > Line:  224  Objects:        8 detected /        0 sextracted
# > Line:  225  Objects:        8 detected /        0 sextracted
# > Line:  226  Objects:        8 detected /        0 sextracted
# > Line:  227  Objects:        9 detected /        0 sextracted
# > Line:  228  Objects:        9 detected /        0 sextracted
# > Line:  229  Objects:        9 detected /        0 sextracted
# > Line:  230  Objects:        9 detected /        0 sextracted
# > Line:  231  Objects:        9 detected /        0 sextracted
# > Line:  232  Objects:        9 detected /        0 sextracted
# > Line:  233  Objects:        9 detected /        0 sextracted
# > Line:  234  Objects:        9 detected /        0 sextracted
# > Line:  235  Objects:        9 detected /        0 sextracted
# > Line:  236  Objects:        9 detected /        0 sextracted
# > Line:  237  Objects:        9 detected /        0 sextracted
# > Line:  238  Objects:        9 detected /        0 sextracted
# > Line:  239  Objects:        9 detected /        0 sextracted
# > Line:  240  Objects:        9 detected /        0 sextracted
# > Line:  241  Objects:        9 detected /        0 sextracted
# > Line:  242  Objects:        9 detected /        0 sextracted
# > Line:  243  Objects:        9 detected /        0 sextracted
# > Line:  244  Objects:        9 detected /        0 sextracted
# > Line:  245  Objects:        9 detected /        0 sextracted
# > Line:  246  Objects:        9 detected /        0 sextracted
# > Line:  247  Objects:        9 detected /        0 sextracted
# > Line:  248  Objects:        9 detected /        0 sextracted
# > Line:  249  Objects:        9 detected /        0 sextracted
# > Line:  250  Objects:        9 detected /        0 sextracted
# > Line:  251  Objects:        9 detected /        0 sextracted
# > Line:  252  Objects:        9 detected /        0 sextracted
# > Line:  253  Objects:        9 detected /        0 sextracted
# > Line:  254  Objects:        9 detected /        0 sextracted
# > Line:  255  Objects:        9 detected /        0 sextracted
# > Line:  256  Objects:        9 detected /        0 sextracted
# > Line:  257  Objects:        9 detected /        0 sextracted
# > Line:  258  Objects:        9 detected /        0 sextracted
# > Line:  259  Objects:        9 detected /        0 sextracted
# > Line:  260  Objects:        9 detected /        0 sextracted
# > Line:  261  Objects:        9 detected /        0 sextracted
# > Line:  262  Objects:        9 detected /        0 sextracted
# > Line:  263  Objects:        9 detected /        0 sextracted
# > Line:  264  Objects:        9 detected /        0 sextracted
# > Line:  265  Objects:        9 detected /        0 sextracted
# > Line:  266  Objects:        9 detected /        0 sextracted
# > Line:  267  Objects:        9 detected /        0 sextracted
# > Line:  268  Objects:        9 detected /        0 sextracted
# > Line:  269  Objects:        9 detected /        0 sextracted
# > Line:  270  Objects:        9 detected /        0 sextracted
# > Line:  271  Objects:        9 detected /        0 sextracted
# > Line:  272  Objects:        9 detected /        0 sextracted
# > Line:  273  Objects:        9 detected /        0 sextracted
# > Line:  274  Objects:        9 detected /        0 sextracted
# > Line:  275  Objects:        9 detected /        0 sextracted
# > Line:  276  Objects:        9 detected /        0 sextracted
# > Line:  277  Objects:        9 detected /        0 sextracted
# > Line:  278  Objects:        9 detected /        0 sextracted
# > Line:  279  Objects:        9 detected /        0 sextracted
# > Line:  280  Objects:        9 detected /        0 sextracted
# > Line:  281  Objects:        9 detected /        0 sextracted
# > Line:  282  Objects:        9 detected /        0 sextracted
# > Line:  283  Objects:        9 detected /        0 sextracted
# > Line:  284  Objects:        9 detected /        0 sextracted
# > Line:  285  Objects:        9 detected /        0 sextracted
# > Line:  286  Objects:        9 detected /        0 sextracted
# > Line:  287  Objects:        9 detected /        0 sextracted
# > Line:  288  Objects:        9 detected /        0 sextracted
# > Line:  289  Objects:        9 detected /        0 sextracted
# > Line:  290  Objects:        9 detected /        0 sextracted
# > Line:  291  Objects:        9 detected /        0 sextracted
# > Line:  292  Objects:        9 detected /        0 sextracted
# > Line:  293  Objects:        9 detected /        0 sextracted
# > Line:  294  Objects:       10 detected /        0 sextracted
# > Line:  295  Objects:       10 detected /        0 sextracted
# > Line:  296  Objects:       10 detected /        0 sextracted
# > Line:  297  Objects:       10 detected /        0 sextracted
# > Line:  298  Objects:       10 detected /        0 sextracted
# > Line:  299  Objects:       10 detected /        0 sextracted
# > Line:  300  Objects:       10 detected /        0 sextracted
# > Line:  301  Objects:       10 detected /        0 sextracted
# > Line:  302  Objects:       10 detected /        0 sextracted
# > Line:  303  Objects:       10 detected /        0 sextracted
# > Line:  304  Objects:       10 detected /        0 sextracted
# > Line:  305  Objects:       10 detected /        0 sextracted
# > Line:  306  Objects:       10 detected /        0 sextracted
# > Line:  307  Objects:       10 detected /        0 sextracted
# > Line:  308  Objects:       10 detected /        0 sextracted
# > Line:  309  Objects:       10 detected /        0 sextracted
# > Line:  310  Objects:       11 detected /        0 sextracted
# > Line:  311  Objects:       11 detected /        0 sextracted
# > Line:  312  Objects:       11 detected /        0 sextracted
# > Line:  313  Objects:       11 detected /        0 sextracted
# > Line:  314  Objects:       11 detected /        0 sextracted
# > Line:  315  Objects:       11 detected /        0 sextracted
# > Line:  316  Objects:       11 detected /        0 sextracted
# > Line:  317  Objects:       12 detected /        0 sextracted
# > Line:  318  Objects:       12 detected /        0 sextracted
# > Line:  319  Objects:       12 detected /        0 sextracted
# > Line:  320  Objects:       12 detected /        0 sextracted
# > Line:  321  Objects:       12 detected /        0 sextracted
# > Line:  322  Objects:       12 detected /        0 sextracted
# > Line:  323  Objects:       13 detected /        0 sextracted
# > Line:  324  Objects:       13 detected /        0 sextracted
# > Line:  325  Objects:       13 detected /        0 sextracted
# > Line:  326  Objects:       13 detected /        0 sextracted
# > Line:  327  Objects:       13 detected /        0 sextracted
# > Line:  328  Objects:       13 detected /        0 sextracted
# > Line:  329  Objects:       13 detected /        0 sextracted
# > Line:  330  Objects:       13 detected /        0 sextracted
# > Line:  331  Objects:       13 detected /        0 sextracted
# > Line:  332  Objects:       13 detected /        0 sextracted
# > Line:  333  Objects:       13 detected /        0 sextracted
# > Line:  334  Objects:       13 detected /        0 sextracted
# > Line:  335  Objects:       13 detected /        0 sextracted
# > Line:  336  Objects:       13 detected /        0 sextracted
# > Line:  337  Objects:       13 detected /        0 sextracted
# > Line:  338  Objects:       13 detected /        0 sextracted
# > Line:  339  Objects:       13 detected /        0 sextracted
# > Line:  340  Objects:       14 detected /        0 sextracted
# > Line:  341  Objects:       14 detected /        0 sextracted
# > Line:  342  Objects:       14 detected /        0 sextracted
# > Line:  343  Objects:       14 detected /        0 sextracted
# > Line:  344  Objects:       14 detected /        0 sextracted
# > Line:  345  Objects:       14 detected /        0 sextracted
# > Line:  346  Objects:       14 detected /        0 sextracted
# > Line:  347  Objects:       14 detected /        0 sextracted
# > Line:  348  Objects:       14 detected /        0 sextracted
# > Line:  349  Objects:       14 detected /        0 sextracted
# > Line:  350  Objects:       14 detected /        0 sextracted
# > Line:  351  Objects:       14 detected /        0 sextracted
# > Line:  352  Objects:       14 detected /        0 sextracted
# > Line:  353  Objects:       14 detected /        0 sextracted
# > Line:  354  Objects:       14 detected /        0 sextracted
# > Line:  355  Objects:       14 detected /        0 sextracted
# > Line:  356  Objects:       14 detected /        0 sextracted
# > Line:  357  Objects:       14 detected /        0 sextracted
# > Line:  358  Objects:       14 detected /        0 sextracted
# > Line:  359  Objects:       14 detected /        0 sextracted
# > Line:  360  Objects:       14 detected /        0 sextracted
# > Line:  361  Objects:       14 detected /        0 sextracted
# > Line:  362  Objects:       14 detected /        0 sextracted
# > Line:  363  Objects:       15 detected /        0 sextracted
# > Line:  364  Objects:       15 detected /        0 sextracted
# > Line:  365  Objects:       15 detected /        0 sextracted
# > Line:  366  Objects:       15 detected /        0 sextracted
# > Line:  367  Objects:       15 detected /        0 sextracted
# > Line:  368  Objects:       15 detected /        0 sextracted
# > Line:  369  Objects:       15 detected /        0 sextracted
# > Line:  370  Objects:       15 detected /        0 sextracted
# > Line:  371  Objects:       15 detected /        0 sextracted
# > Line:  372  Objects:       15 detected /        0 sextracted
# > Line:  373  Objects:       15 detected /        0 sextracted
# > Line:  374  Objects:       15 detected /        0 sextracted
# > Line:  375  Objects:       15 detected /        0 sextracted
# > Line:  376  Objects:       15 detected /        0 sextracted
# > Line:  377  Objects:       15 detected /        0 sextracted
# > Line:  378  Objects:       15 detected /        0 sextracted
# > Line:  379  Objects:       15 detected /        0 sextracted
# > Line:  380  Objects:       15 detected /        0 sextracted
# > Line:  381  Objects:       15 detected /        0 sextracted
# > Line:  382  Objects:       15 detected /        0 sextracted
# > Line:  383  Objects:       15 detected /        0 sextracted
# > Line:  384  Objects:       15 detected /        0 sextracted
# > Line:  385  Objects:       15 detected /        0 sextracted
# > Line:  386  Objects:       15 detected /        0 sextracted
# > Line:  387  Objects:       16 detected /        0 sextracted
# > Line:  388  Objects:       16 detected /        0 sextracted
# > Line:  389  Objects:       16 detected /        0 sextracted
# > Line:  390  Objects:       16 detected /        0 sextracted
# > Line:  391  Objects:       16 detected /        0 sextracted
# > Line:  392  Objects:       16 detected /        0 sextracted
# > Line:  393  Objects:       16 detected /        0 sextracted
# > Line:  394  Objects:       16 detected /        0 sextracted
# > Line:  395  Objects:       16 detected /        0 sextracted
# > Line:  396  Objects:       16 detected /        0 sextracted
# > Line:  397  Objects:       16 detected /        0 sextracted
# > Line:  398  Objects:       16 detected /        0 sextracted
# > Line:  399  Objects:       16 detected /        0 sextracted
# > Line:  400  Objects:       16 detected /        0 sextracted
# > Line:  401  Objects:       17 detected /        0 sextracted
# > Line:  402  Objects:       17 detected /        0 sextracted
# > Line:  403  Objects:       17 detected /        0 sextracted
# > Line:  404  Objects:       17 detected /        0 sextracted
# > Line:  405  Objects:       17 detected /        0 sextracted
# > Line:  406  Objects:       17 detected /        0 sextracted
# > Line:  407  Objects:       17 detected /        0 sextracted
# > Line:  408  Objects:       18 detected /        0 sextracted
# > Line:  409  Objects:       18 detected /        0 sextracted
# > Line:  410  Objects:       18 detected /        0 sextracted
# > Line:  411  Objects:       18 detected /        0 sextracted
# > Line:  412  Objects:       18 detected /        0 sextracted
# > Line:  413  Objects:       18 detected /        0 sextracted
# > Line:  414  Objects:       18 detected /        0 sextracted
# > Line:  415  Objects:       18 detected /        0 sextracted
# > Line:  416  Objects:       18 detected /        0 sextracted
# > Line:  417  Objects:       18 detected /        0 sextracted
# > Line:  418  Objects:       18 detected /        0 sextracted
# > Line:  419  Objects:       18 detected /        0 sextracted
# > Line:  420  Objects:       18 detected /        0 sextracted
# > Line:  421  Objects:       18 detected /        0 sextracted
# > Line:  422  Objects:       18 detected /        0 sextracted
# > Line:  423  Objects:       18 detected /        0 sextracted
# > Line:  424  Objects:       18 detected /        0 sextracted
# > Line:  425  Objects:       18 detected /        0 sextracted
# > Line:  426  Objects:       18 detected /        0 sextracted
# > Line:  427  Objects:       18 detected /        0 sextracted
# > Line:  428  Objects:       18 detected /        0 sextracted
# > Line:  429  Objects:       18 detected /        0 sextracted
# > Line:  430  Objects:       18 detected /        0 sextracted
# > Line:  431  Objects:       18 detected /        0 sextracted
# > Line:  432  Objects:       18 detected /        0 sextracted
# > Line:  433  Objects:       18 detected /        0 sextracted
# > Line:  434  Objects:       18 detected /        0 sextracted
# > Line:  435  Objects:       18 detected /        0 sextracted
# > Line:  436  Objects:       18 detected /        0 sextracted
# > Line:  437  Objects:       18 detected /        0 sextracted
# > Line:  438  Objects:       18 detected /        0 sextracted
# > Line:  439  Objects:       18 detected /        0 sextracted
# > Line:  440  Objects:       18 detected /        0 sextracted
# > Line:  441  Objects:       18 detected /        0 sextracted
# > Line:  442  Objects:       18 detected /        0 sextracted
# > Line:  443  Objects:       18 detected /        0 sextracted
# > Line:  444  Objects:       18 detected /        0 sextracted
# > Line:  445  Objects:       18 detected /        0 sextracted
# > Line:  446  Objects:       18 detected /        0 sextracted
# > Line:  447  Objects:       18 detected /        0 sextracted
# > Line:  448  Objects:       18 detected /        0 sextracted
# > Line:  449  Objects:       18 detected /        0 sextracted
# > Line:  450  Objects:       18 detected /        0 sextracted
# > Line:  451  Objects:       18 detected /        0 sextracted
# > Line:  452  Objects:       18 detected /        0 sextracted
# > Line:  453  Objects:       18 detected /        0 sextracted
# > Line:  454  Objects:       18 detected /        0 sextracted
# > Line:  455  Objects:       18 detected /        0 sextracted
# > Line:  456  Objects:       18 detected /        0 sextracted
# > Line:  457  Objects:       18 detected /        0 sextracted
# > Line:  458  Objects:       18 detected /        0 sextracted
# > Line:  459  Objects:       18 detected /        0 sextracted
# > Line:  460  Objects:       18 detected /        0 sextracted
# > Line:  461  Objects:       18 detected /        0 sextracted
# > Line:  462  Objects:       18 detected /        0 sextracted
# > Line:  463  Objects:       18 detected /        0 sextracted
# > Line:  464  Objects:       18 detected /        0 sextracted
# > Line:  465  Objects:       18 detected /        0 sextracted
# > Line:  466  Objects:       18 detected /        0 sextracted
# > Line:  467  Objects:       18 detected /        0 sextracted
# > Line:  468  Objects:       18 detected /        0 sextracted
# > Line:  469  Objects:       18 detected /        0 sextracted
# > Line:  470  Objects:       18 detected /        0 sextracted
# > Line:  471  Objects:       18 detected /        0 sextracted
# > Line:  472  Objects:       18 detected /        0 sextracted
# > Line:  473  Objects:       18 detected /        0 sextracted
# > Line:  474  Objects:       18 detected /        0 sextracted
# > Line:  475  Objects:       18 detected /        0 sextracted
# > Line:  476  Objects:       18 detected /        0 sextracted
# > Line:  477  Objects:       18 detected /        0 sextracted
# > Line:  478  Objects:       18 detected /        0 sextracted
# > Line:  479  Objects:       18 detected /        0 sextracted
# > Line:  480  Objects:       18 detected /        0 sextracted
# > Line:  481  Objects:       18 detected /        0 sextracted
# > Line:  482  Objects:       18 detected /        0 sextracted
# > Line:  483  Objects:       18 detected /        0 sextracted
# > Line:  484  Objects:       18 detected /        0 sextracted
# > Line:  485  Objects:       18 detected /        0 sextracted
# > Line:  486  Objects:       18 detected /        0 sextracted
# > Line:  487  Objects:       18 detected /        0 sextracted
# > Line:  488  Objects:       18 detected /        0 sextracted
# > Line:  489  Objects:       18 detected /        0 sextracted
# > Line:  490  Objects:       18 detected /        0 sextracted
# > Line:  491  Objects:       18 detected /        0 sextracted
# > Line:  492  Objects:       18 detected /        0 sextracted
# > Line:  493  Objects:       18 detected /        0 sextracted
# > Line:  494  Objects:       18 detected /        0 sextracted
# > Line:  495  Objects:       18 detected /        0 sextracted
# > Line:  496  Objects:       18 detected /        0 sextracted
# > Line:  497  Objects:       18 detected /        0 sextracted
# > Line:  498  Objects:       18 detected /        0 sextracted
# > Line:  499  Objects:       18 detected /        0 sextracted
# > Line:  500  Objects:       19 detected /        0 sextracted
# > Line:  501  Objects:       19 detected /        0 sextracted
# > Line:  502  Objects:       19 detected /        0 sextracted
# > Line:  503  Objects:       19 detected /        0 sextracted
# > Line:  504  Objects:       19 detected /        0 sextracted
# > Line:  505  Objects:       19 detected /        0 sextracted
# > Line:  506  Objects:       19 detected /        0 sextracted
# > Line:  507  Objects:       19 detected /        0 sextracted
# > Line:  508  Objects:       19 detected /        0 sextracted
# > Line:  509  Objects:       19 detected /        0 sextracted
# > Line:  510  Objects:       19 detected /        0 sextracted
# > Line:  511  Objects:       19 detected /        0 sextracted
# > Line:  512  Objects:       19 detected /        0 sextracted
# > Line:  513  Objects:       19 detected /        0 sextracted
# > Line:  514  Objects:       19 detected /        0 sextracted
# > Line:  515  Objects:       20 detected /        0 sextracted
# > Line:  516  Objects:       20 detected /        0 sextracted
# > Line:  517  Objects:       20 detected /        0 sextracted
# > Line:  518  Objects:       20 detected /        0 sextracted
# > Line:  519  Objects:       20 detected /        0 sextracted
# > Line:  520  Objects:       20 detected /        0 sextracted
# > Line:  521  Objects:       20 detected /        0 sextracted
# > Line:  522  Objects:       20 detected /        0 sextracted
# > Line:  523  Objects:       20 detected /        0 sextracted
# > Line:  524  Objects:       20 detected /        0 sextracted
# > Line:  525  Objects:       20 detected /        0 sextracted
# > Line:  526  Objects:       20 detected /        0 sextracted
# > Line:  527  Objects:       20 detected /        0 sextracted
# > Line:  528  Objects:       20 detected /        0 sextracted
# > Line:  529  Objects:       20 detected /        0 sextracted
# > Line:  530  Objects:       20 detected /        0 sextracted
# > Line:  531  Objects:       20 detected /        0 sextracted
# > Line:  532  Objects:       20 detected /        0 sextracted
# > Line:  533  Objects:       20 detected /        0 sextracted
# > Line:  534  Objects:       20 detected /        0 sextracted
# > Line:  535  Objects:       20 detected /        0 sextracted
# > Line:  536  Objects:       20 detected /        0 sextracted
# > Line:  537  Objects:       20 detected /        0 sextracted
# > Line:  538  Objects:       21 detected /        0 sextracted
# > Line:  539  Objects:       21 detected /        0 sextracted
# > Line:  540  Objects:       21 detected /        0 sextracted
# > Line:  541  Objects:       21 detected /        0 sextracted
# > Line:  542  Objects:       22 detected /        0 sextracted
# > Line:  543  Objects:       22 detected /        0 sextracted
# > Line:  544  Objects:       22 detected /        0 sextracted
# > Line:  545  Objects:       22 detected /        0 sextracted
# > Line:  546  Objects:       22 detected /        0 sextracted
# > Line:  547  Objects:       22 detected /        0 sextracted
# > Line:  548  Objects:       23 detected /        0 sextracted
# > Line:  549  Objects:       23 detected /        0 sextracted
# > Line:  550  Objects:       23 detected /        0 sextracted
# > Line:  551  Objects:       23 detected /        0 sextracted
# > Line:  552  Objects:       23 detected /        0 sextracted
# > Line:  553  Objects:       23 detected /        0 sextracted
# > Line:  554  Objects:       23 detected /        0 sextracted
# > Line:  555  Objects:       23 detected /        0 sextracted
# > Line:  556  Objects:       23 detected /        0 sextracted
# > Line:  557  Objects:       23 detected /        0 sextracted
# > Line:  558  Objects:       23 detected /        0 sextracted
# > Line:  559  Objects:       23 detected /        0 sextracted
# > Line:  560  Objects:       23 detected /        0 sextracted
# > Line:  561  Objects:       23 detected /        0 sextracted
# > Line:  562  Objects:       23 detected /        0 sextracted
# > Line:  563  Objects:       23 detected /        0 sextracted
# > Line:  564  Objects:       23 detected /        0 sextracted
# > Line:  565  Objects:       23 detected /        0 sextracted
# > Line:  566  Objects:       23 detected /        0 sextracted
# > Line:  567  Objects:       23 detected /        0 sextracted
# > Line:  568  Objects:       23 detected /        0 sextracted
# > Line:  569  Objects:       24 detected /        0 sextracted
# > Line:  570  Objects:       24 detected /        0 sextracted
# > Line:  571  Objects:       24 detected /        0 sextracted
# > Line:  572  Objects:       24 detected /        0 sextracted
# > Line:  573  Objects:       24 detected /        0 sextracted
# > Line:  574  Objects:       24 detected /        0 sextracted
# > Line:  575  Objects:       24 detected /        0 sextracted
# > Line:  576  Objects:       24 detected /        0 sextracted
# > Line:  577  Objects:       24 detected /        0 sextracted
# > Line:  578  Objects:       24 detected /        0 sextracted
# > Line:  579  Objects:       24 detected /        0 sextracted
# > Line:  580  Objects:       24 detected /        0 sextracted
# > Line:  581  Objects:       24 detected /        0 sextracted
# > Line:  582  Objects:       24 detected /        0 sextracted
# > Line:  583  Objects:       25 detected /        0 sextracted
# > Line:  584  Objects:       25 detected /        0 sextracted
# > Line:  585  Objects:       25 detected /        0 sextracted
# > Line:  586  Objects:       25 detected /        0 sextracted
# > Line:  587  Objects:       25 detected /        0 sextracted
# > Line:  588  Objects:       25 detected /        0 sextracted
# > Line:  589  Objects:       25 detected /        0 sextracted
# > Line:  590  Objects:       25 detected /        0 sextracted
# > Line:  591  Objects:       25 detected /        0 sextracted
# > Line:  592  Objects:       25 detected /        0 sextracted
# > Line:  593  Objects:       25 detected /        0 sextracted
# > Line:  594  Objects:       25 detected /        0 sextracted
# > Line:  595  Objects:       25 detected /        0 sextracted
# > Line:  596  Objects:       25 detected /        0 sextracted
# > Line:  597  Objects:       25 detected /        0 sextracted
# > Line:  598  Objects:       25 detected /        0 sextracted
# > Line:  599  Objects:       25 detected /        0 sextracted
# > Line:  600  Objects:       25 detected /        0 sextracted
# > Line:  601  Objects:       25 detected /        0 sextracted
# > Line:  602  Objects:       25 detected /        0 sextracted
# > Line:  603  Objects:       25 detected /        0 sextracted
# > Line:  604  Objects:       25 detected /        0 sextracted
# > Line:  605  Objects:       25 detected /        0 sextracted
# > Line:  606  Objects:       25 detected /        0 sextracted
# > Line:  607  Objects:       25 detected /        0 sextracted
# > Line:  608  Objects:       25 detected /        0 sextracted
# > Line:  609  Objects:       25 detected /        0 sextracted
# > Line:  610  Objects:       25 detected /        0 sextracted
# > Line:  611  Objects:       25 detected /        0 sextracted
# > Line:  612  Objects:       25 detected /        0 sextracted
# > Line:  613  Objects:       25 detected /        0 sextracted
# > Line:  614  Objects:       25 detected /        0 sextracted
# > Line:  615  Objects:       25 detected /        0 sextracted
# > Line:  616  Objects:       26 detected /        0 sextracted
# > Line:  617  Objects:       26 detected /        0 sextracted
# > Line:  618  Objects:       26 detected /        0 sextracted
# > Line:  619  Objects:       26 detected /        0 sextracted
# > Line:  620  Objects:       26 detected /        0 sextracted
# > Line:  621  Objects:       26 detected /        0 sextracted
# > Line:  622  Objects:       26 detected /        0 sextracted
# > Line:  623  Objects:       26 detected /        0 sextracted
# > Line:  624  Objects:       26 detected /        0 sextracted
# > Line:  625  Objects:       27 detected /        0 sextracted
# > Line:  626  Objects:       27 detected /        0 sextracted
# > Line:  627  Objects:       27 detected /        0 sextracted
# > Line:  628  Objects:       27 detected /        0 sextracted
# > Line:  629  Objects:       27 detected /        0 sextracted
# > Line:  630  Objects:       27 detected /        0 sextracted
# > Line:  631  Objects:       27 detected /        0 sextracted
# > Line:  632  Objects:       27 detected /        0 sextracted
# > Line:  633  Objects:       27 detected /        0 sextracted
# > Line:  634  Objects:       27 detected /        0 sextracted
# > Line:  635  Objects:       27 detected /        0 sextracted
# > Line:  636  Objects:       27 detected /        0 sextracted
# > Line:  637  Objects:       27 detected /        0 sextracted
# > Line:  638  Objects:       28 detected /        0 sextracted
# > Line:  639  Objects:       28 detected /        0 sextracted
# > Line:  640  Objects:       28 detected /        0 sextracted
# > Line:  641  Objects:       28 detected /        0 sextracted
# > Line:  642  Objects:       28 detected /        0 sextracted
# > Line:  643  Objects:       28 detected /        0 sextracted
# > Line:  644  Objects:       28 detected /        0 sextracted
# > Line:  645  Objects:       28 detected /        0 sextracted
# > Line:  646  Objects:       28 detected /        0 sextracted
# > Line:  647  Objects:       28 detected /        0 sextracted
# > Line:  648  Objects:       28 detected /        0 sextracted
# > Line:  649  Objects:       28 detected /        0 sextracted
# > Line:  650  Objects:       28 detected /        0 sextracted
# > Line:  651  Objects:       28 detected /        0 sextracted
# > Line:  652  Objects:       28 detected /        0 sextracted
# > Line:  653  Objects:       28 detected /        0 sextracted
# > Line:  654  Objects:       28 detected /        0 sextracted
# > Line:  655  Objects:       28 detected /        0 sextracted
# > Line:  656  Objects:       28 detected /        0 sextracted
# > Line:  657  Objects:       28 detected /        0 sextracted
# > Line:  658  Objects:       28 detected /        0 sextracted
# > Line:  659  Objects:       28 detected /        0 sextracted
# > Line:  660  Objects:       28 detected /        0 sextracted
# > Line:  661  Objects:       28 detected /        0 sextracted
# > Line:  662  Objects:       28 detected /        0 sextracted
# > Line:  663  Objects:       28 detected /        0 sextracted
# > Line:  664  Objects:       28 detected /        0 sextracted
# > Line:  665  Objects:       29 detected /        0 sextracted
# > Line:  666  Objects:       29 detected /        0 sextracted
# > Line:  667  Objects:       29 detected /        0 sextracted
# > Line:  668  Objects:       29 detected /        0 sextracted
# > Line:  669  Objects:       29 detected /        0 sextracted
# > Line:  670  Objects:       29 detected /        0 sextracted
# > Line:  671  Objects:       29 detected /        0 sextracted
# > Line:  672  Objects:       29 detected /        0 sextracted
# > Line:  673  Objects:       29 detected /        0 sextracted
# > Line:  674  Objects:       29 detected /        0 sextracted
# > Line:  675  Objects:       29 detected /        0 sextracted
# > Line:  676  Objects:       29 detected /        0 sextracted
# > Line:  677  Objects:       29 detected /        0 sextracted
# > Line:  678  Objects:       29 detected /        0 sextracted
# > Line:  679  Objects:       29 detected /        0 sextracted
# > Line:  680  Objects:       29 detected /        0 sextracted
# > Line:  681  Objects:       29 detected /        0 sextracted
# > Line:  682  Objects:       29 detected /        0 sextracted
# > Line:  683  Objects:       29 detected /        0 sextracted
# > Line:  684  Objects:       29 detected /        0 sextracted
# > Line:  685  Objects:       29 detected /        0 sextracted
# > Line:  686  Objects:       29 detected /        0 sextracted
# > Line:  687  Objects:       29 detected /        0 sextracted
# > Line:  688  Objects:       29 detected /        0 sextracted
# > Line:  689  Objects:       29 detected /        0 sextracted
# > Line:  690  Objects:       29 detected /        0 sextracted
# > Line:  691  Objects:       29 detected /        0 sextracted
# > Line:  692  Objects:       29 detected /        0 sextracted
# > Line:  693  Objects:       29 detected /        0 sextracted
# > Line:  694  Objects:       29 detected /        0 sextracted
# > Line:  695  Objects:       29 detected /        0 sextracted
# > Line:  696  Objects:       29 detected /        0 sextracted
# > Line:  697  Objects:       29 detected /        0 sextracted
# > Line:  698  Objects:       29 detected /        0 sextracted
# > Line:  699  Objects:       29 detected /        0 sextracted
# > Line:  700  Objects:       30 detected /        0 sextracted
# > Line:  701  Objects:       30 detected /        0 sextracted
# > Line:  702  Objects:       30 detected /        0 sextracted
# > Line:  703  Objects:       30 detected /        0 sextracted
# > Line:  704  Objects:       30 detected /        0 sextracted
# > Line:  705  Objects:       30 detected /        0 sextracted
# > Line:  706  Objects:       30 detected /        0 sextracted
# > Line:  707  Objects:       30 detected /        0 sextracted
# > Line:  708  Objects:       30 detected /        0 sextracted
# > Line:  709  Objects:       30 detected /        0 sextracted
# > Line:  710  Objects:       30 detected /        0 sextracted
# > Line:  711  Objects:       30 detected /        0 sextracted
# > Line:  712  Objects:       30 detected /        0 sextracted
# > Line:  713  Objects:       30 detected /        0 sextracted
# > Line:  714  Objects:       30 detected /        0 sextracted
# > Line:  715  Objects:       30 detected /        0 sextracted
# > Line:  716  Objects:       30 detected /        0 sextracted
# > Line:  717  Objects:       30 detected /        0 sextracted
# > Line:  718  Objects:       30 detected /        0 sextracted
# > Line:  719  Objects:       30 detected /        0 sextracted
# > Line:  720  Objects:       30 detected /        0 sextracted
# > Line:  721  Objects:       30 detected /        0 sextracted
# > Line:  722  Objects:       30 detected /        0 sextracted
# > Line:  723  Objects:       30 detected /        0 sextracted
# > Line:  724  Objects:       30 detected /        0 sextracted
# > Line:  725  Objects:       30 detected /        0 sextracted
# > Line:  726  Objects:       30 detected /        0 sextracted
# > Line:  727  Objects:       30 detected /        0 sextracted
# > Line:  728  Objects:       30 detected /        0 sextracted
# > Line:  729  Objects:       30 detected /        0 sextracted
# > Line:  730  Objects:       30 detected /        0 sextracted
# > Line:  731  Objects:       30 detected /        0 sextracted
# > Line:  732  Objects:       30 detected /        0 sextracted
# > Line:  733  Objects:       31 detected /        0 sextracted
# > Line:  734  Objects:       32 detected /        0 sextracted
# > Line:  735  Objects:       32 detected /        0 sextracted
# > Line:  736  Objects:       32 detected /        0 sextracted
# > Line:  737  Objects:       32 detected /        0 sextracted
# > Line:  738  Objects:       32 detected /        0 sextracted
# > Line:  739  Objects:       32 detected /        0 sextracted
# > Line:  740  Objects:       32 detected /        0 sextracted
# > Line:  741  Objects:       32 detected /        0 sextracted
# > Line:  742  Objects:       32 detected /        0 sextracted
# > Line:  743  Objects:       32 detected /        0 sextracted
# > Line:  744  Objects:       32 detected /        0 sextracted
# ...
# > Line: 1856  Objects:       92 detected /       40 sextracted
# > Line: 1857  Objects:       92 detected /       40 sextracted
# > Line: 1858  Objects:       92 detected /       40 sextracted
# > Line: 1859  Objects:       92 detected /       40 sextracted
# > Line: 1860  Objects:       92 detected /       40 sextracted
# > Line: 1861  Objects:       92 detected /       40 sextracted
# > Line: 1862  Objects:       92 detected /       40 sextracted
# > Line: 1863  Objects:       92 detected /       40 sextracted
# > Line: 1864  Objects:       92 detected /       40 sextracted
# > Line: 1865  Objects:       92 detected /       40 sextracted
# > Line: 1866  Objects:       92 detected /       40 sextracted
# > Line: 1867  Objects:       92 detected /       40 sextracted
# > Line: 1868  Objects:       92 detected /       40 sextracted
# > Line: 1869  Objects:       92 detected /       40 sextracted
# > Line: 1870  Objects:       92 detected /       40 sextracted
# > Line: 1871  Objects:       92 detected /       40 sextracted
# > Line: 1872  Objects:       93 detected /       40 sextracted
# > Line: 1873  Objects:       93 detected /       40 sextracted
# > Line: 1874  Objects:       93 detected /       40 sextracted
# > Line: 1875  Objects:       93 detected /       40 sextracted
# > Line: 1876  Objects:       93 detected /       40 sextracted
# > Line: 1877  Objects:       93 detected /       40 sextracted
# > Line: 1878  Objects:       93 detected /       40 sextracted
# > Line: 1879  Objects:       93 detected /       40 sextracted
# > Line: 1900  Objects:       95 detected /       41 sextracted
# > Line: 1925  Objects:       97 detected /       43 sextracted
# > Line: 1950  Objects:      100 detected /       43 sextracted
# > Line: 1975  Objects:      101 detected /       43 sextracted
# > Line: 2000  Objects:      102 detected /       43 sextracted
# > Line: 2025  Objects:      102 detected /       43 sextracted
# > Line: 2050  Objects:      104 detected /       44 sextracted
# > Line: 2075  Objects:      105 detected /       46 sextracted
# > Line: 2100  Objects:      106 detected /       47 sextracted
# > Line: 2125  Objects:      108 detected /       49 sextracted
# > Line: 2131  Objects:      108 detected /       50 sextracted
# > Line: 2132  Objects:      108 detected /       50 sextracted
# > Line: 2133  Objects:      108 detected /       50 sextracted
# > Line: 2134  Objects:      108 detected /       50 sextracted
# > Line: 2135  Objects:      108 detected /       50 sextracted
# > Line: 2136  Objects:      108 detected /       50 sextracted
# > Line: 2137  Objects:      108 detected /       50 sextracted
# > Line: 2138  Objects:      108 detected /       50 sextracted
# > Line: 2139  Objects:      108 detected /       50 sextracted
# > Line: 2140  Objects:      108 detected /       50 sextracted
# > Line: 2141  Objects:      108 detected /       50 sextracted
# > Line: 2142  Objects:      108 detected /       50 sextracted
# > Line: 2143  Objects:      108 detected /       50 sextracted
# > Line: 2144  Objects:      108 detected /       50 sextracted
# > Line: 2145  Objects:      108 detected /       50 sextracted
# > Line: 2146  Objects:      108 detected /       50 sextracted
# > Line: 2150  Objects:      108 detected /       51 sextracted
# > Line: 2175  Objects:      108 detected /       53 sextracted
# > Line: 2200  Objects:      109 detected /       56 sextracted
# > Line: 2225  Objects:      109 detected /       56 sextracted
# > Line: 2250  Objects:      110 detected /       57 sextracted
# > Line: 2270  Objects:      110 detected /       60 sextracted
# > Line: 2271  Objects:      110 detected /       60 sextracted
# > Line: 2272  Objects:      110 detected /       60 sextracted
# > Line: 2273  Objects:      110 detected /       60 sextracted
# > Line: 2274  Objects:      110 detected /       60 sextracted
# > Line: 2275  Objects:      111 detected /       60 sextracted
# > Line: 2276  Objects:      111 detected /       60 sextracted
# > Line: 2277  Objects:      111 detected /       60 sextracted
# > Line: 2278  Objects:      111 detected /       60 sextracted
# > Line: 2300  Objects:      111 detected /       61 sextracted
# > Line: 2325  Objects:      111 detected /       64 sextracted
# > Line: 2350  Objects:      114 detected /       66 sextracted
# > Line: 2375  Objects:      116 detected /       67 sextracted
# > Line: 2400  Objects:      118 detected /       67 sextracted
# > Line: 2423  Objects:      120 detected /       70 sextracted
# > Line: 2424  Objects:      120 detected /       70 sextracted
# > Line: 2425  Objects:      121 detected /       70 sextracted
# > Line: 2426  Objects:      121 detected /       70 sextracted
# > Line: 2427  Objects:      121 detected /       70 sextracted
# > Line: 2428  Objects:      121 detected /       70 sextracted
# > Line: 2429  Objects:      121 detected /       70 sextracted
# > Line: 2430  Objects:      121 detected /       70 sextracted
# > Line: 2431  Objects:      121 detected /       70 sextracted
# > Line: 2432  Objects:      122 detected /       70 sextracted
# > Line: 2433  Objects:      122 detected /       70 sextracted
# > Line: 2434  Objects:      122 detected /       70 sextracted
# > Line: 2435  Objects:      122 detected /       70 sextracted
# > Line: 2436  Objects:      123 detected /       70 sextracted
# > Line: 2437  Objects:      123 detected /       70 sextracted
# > Line: 2438  Objects:      123 detected /       70 sextracted
# > Line: 2439  Objects:      123 detected /       70 sextracted
# > Line: 2440  Objects:      123 detected /       70 sextracted
# > Line: 2441  Objects:      123 detected /       70 sextracted
# > Line: 2442  Objects:      123 detected /       70 sextracted
# > Line: 2450  Objects:      123 detected /       71 sextracted
# > Line: 2475  Objects:      124 detected /       72 sextracted
# > Line: 2500  Objects:      124 detected /       73 sextracted
# > Line: 2525  Objects:      127 detected /       75 sextracted
# > Line: 2550  Objects:      128 detected /       77 sextracted
# > Line: 2575  Objects:      129 detected /       78 sextracted
# > Line: 2600  Objects:      133 detected /       78 sextracted
# > Line: 2625  Objects:      134 detected /       78 sextracted
# > Line: 2650  Objects:      136 detected /       79 sextracted
# > Line: 2664  Objects:      136 detected /       80 sextracted
# > Line: 2665  Objects:      136 detected /       80 sextracted
# > Line: 2666  Objects:      136 detected /       80 sextracted
# > Line: 2667  Objects:      136 detected /       80 sextracted
# > Line: 2668  Objects:      136 detected /       80 sextracted
# > Line: 2669  Objects:      136 detected /       80 sextracted
# > Line: 2670  Objects:      137 detected /       80 sextracted
# > Line: 2671  Objects:      137 detected /       80 sextracted
# > Line: 2675  Objects:      137 detected /       81 sextracted
# > Line: 2700  Objects:      139 detected /       82 sextracted
# > Line: 2725  Objects:      142 detected /       82 sextracted
# > Line: 2750  Objects:      145 detected /       82 sextracted
# > Line: 2775  Objects:      147 detected /       86 sextracted
# > Line: 2800  Objects:      148 detected /       86 sextracted
# > Line: 2825  Objects:      150 detected /       87 sextracted
# > Line: 2846  Objects:      152 detected /       90 sextracted
# > Line: 2847  Objects:      152 detected /       90 sextracted
# > Line: 2848  Objects:      152 detected /       90 sextracted
# > Line: 2849  Objects:      152 detected /       90 sextracted
# > Line: 2850  Objects:      152 detected /       90 sextracted
# > Line: 2851  Objects:      152 detected /       90 sextracted
# > Line: 2875  Objects:      154 detected /       93 sextracted
# > Line: 2900  Objects:      155 detected /       95 sextracted
# > Line: 2925  Objects:      158 detected /       96 sextracted
# > Line: 2943  Objects:      159 detected /      100 sextracted
# > Line: 2944  Objects:      160 detected /      100 sextracted
# > Line: 2945  Objects:      161 detected /      100 sextracted
# > Line: 2946  Objects:      161 detected /      100 sextracted
# > Line: 2947  Objects:      162 detected /      100 sextracted
# > Line: 2948  Objects:      162 detected /      100 sextracted
# > Line: 2949  Objects:      162 detected /      100 sextracted
# > Line: 2950  Objects:      162 detected /      100 sextracted
# > Line: 2951  Objects:      162 detected /      100 sextracted
# > Line: 2952  Objects:      162 detected /      100 sextracted
# > Line: 2953  Objects:      162 detected /      100 sextracted
# > Line: 2954  Objects:      162 detected /      100 sextracted
# > Line: 2955  Objects:      162 detected /      100 sextracted
# > Line: 2956  Objects:      162 detected /      100 sextracted
# > Line: 2957  Objects:      162 detected /      100 sextracted
# > Line: 2958  Objects:      162 detected /      100 sextracted
# > Line: 2959  Objects:      162 detected /      100 sextracted
# > Line: 2960  Objects:      162 detected /      100 sextracted
# > Line: 2961  Objects:      162 detected /      100 sextracted
# > Line: 2962  Objects:      162 detected /      100 sextracted
# > Line: 2963  Objects:      162 detected /      100 sextracted
# > Line: 2975  Objects:      165 detected /      101 sextracted
# > Line: 3000  Objects:      168 detected /      102 sextracted
# > Line: 3025  Objects:      170 detected /      102 sextracted
# > Line: 3050  Objects:      173 detected /      104 sextracted
# > Line: 3075  Objects:      175 detected /      106 sextracted
# > Line: 3100  Objects:      177 detected /      106 sextracted
# > Line: 3125  Objects:      177 detected /      108 sextracted
# > Line: 3150  Objects:      178 detected /      108 sextracted
# > Line: 3175  Objects:      179 detected /      108 sextracted
# > Line: 3200  Objects:      181 detected /      109 sextracted
# > Line: 3225  Objects:      181 detected /      109 sextracted
# > Line: 3237  Objects:      182 detected /      110 sextracted
# > Line: 3238  Objects:      182 detected /      110 sextracted
# > Line: 3239  Objects:      182 detected /      110 sextracted
# > Line: 3240  Objects:      182 detected /      110 sextracted
# > Line: 3241  Objects:      182 detected /      110 sextracted
# > Line: 3242  Objects:      183 detected /      110 sextracted
# > Line: 3243  Objects:      183 detected /      110 sextracted
# > Line: 3244  Objects:      183 detected /      110 sextracted
# > Line: 3245  Objects:      183 detected /      110 sextracted
# > Line: 3246  Objects:      183 detected /      110 sextracted
# > Line: 3247  Objects:      183 detected /      110 sextracted
# > Line: 3248  Objects:      183 detected /      110 sextracted
# > Line: 3249  Objects:      183 detected /      110 sextracted
# > Line: 3250  Objects:      183 detected /      110 sextracted
# > Line: 3251  Objects:      183 detected /      110 sextracted
# > Line: 3252  Objects:      183 detected /      110 sextracted
# > Line: 3253  Objects:      183 detected /      110 sextracted
# > Line: 3254  Objects:      183 detected /      110 sextracted
# > Line: 3255  Objects:      183 detected /      110 sextracted
# > Line: 3256  Objects:      183 detected /      110 sextracted
# > Line: 3257  Objects:      183 detected /      110 sextracted
# > Line: 3258  Objects:      183 detected /      110 sextracted
# > Line: 3259  Objects:      183 detected /      110 sextracted
# > Line: 3260  Objects:      183 detected /      110 sextracted
# > Line: 3261  Objects:      183 detected /      110 sextracted
# > Line: 3262  Objects:      183 detected /      110 sextracted
# > Line: 3263  Objects:      183 detected /      110 sextracted
# > Line: 3264  Objects:      183 detected /      110 sextracted
# > Line: 3265  Objects:      183 detected /      110 sextracted
# > Line: 3266  Objects:      183 detected /      110 sextracted
# > Line: 3267  Objects:      183 detected /      110 sextracted
# > Line: 3268  Objects:      183 detected /      110 sextracted
# > Line: 3269  Objects:      183 detected /      110 sextracted
# > Line: 3270  Objects:      183 detected /      110 sextracted
# > Line: 3271  Objects:      183 detected /      110 sextracted
# > Line: 3272  Objects:      184 detected /      110 sextracted
# > Line: 3273  Objects:      184 detected /      110 sextracted
# > Line: 3274  Objects:      185 detected /      110 sextracted
# > Line: 3275  Objects:      186 detected /      110 sextracted
# > Line: 3276  Objects:      186 detected /      110 sextracted
# > Line: 3277  Objects:      186 detected /      110 sextracted
# > Line: 3278  Objects:      186 detected /      110 sextracted
# > Line: 3279  Objects:      186 detected /      110 sextracted
# > Line: 3280  Objects:      186 detected /      110 sextracted
# > Line: 3281  Objects:      186 detected /      110 sextracted
# > Line: 3300  Objects:      188 detected /      111 sextracted
# > Line: 3325  Objects:      190 detected /      112 sextracted
# > Line: 3350  Objects:      191 detected /      115 sextracted
# > Line: 3375  Objects:      192 detected /      115 sextracted
# > Line: 3400  Objects:      193 detected /      117 sextracted
# > Line: 3422  Objects:      194 detected /      120 sextracted
# > Line: 3423  Objects:      194 detected /      120 sextracted
# > Line: 3425  Objects:      194 detected /      121 sextracted
# > Line: 3450  Objects:      197 detected /      122 sextracted
# > Line: 3475  Objects:      198 detected /      123 sextracted
# > Line: 3500  Objects:      201 detected /      123 sextracted
# > Line: 3525  Objects:      204 detected /      126 sextracted
# > Line: 3550  Objects:      206 detected /      127 sextracted
# > Line: 3575  Objects:      206 detected /      129 sextracted
# > Line: 3579  Objects:      206 detected /      130 sextracted
# > Line: 3580  Objects:      206 detected /      130 sextracted
# > Line: 3581  Objects:      206 detected /      130 sextracted
# > Line: 3582  Objects:      206 detected /      130 sextracted
# > Line: 3583  Objects:      206 detected /      130 sextracted
# > Line: 3584  Objects:      206 detected /      130 sextracted
# > Line: 3585  Objects:      206 detected /      130 sextracted
# > Line: 3600  Objects:      206 detected /      133 sextracted
# > Line: 3625  Objects:      208 detected /      133 sextracted
# > Line: 3650  Objects:      208 detected /      135 sextracted
# > Line: 3675  Objects:      211 detected /      137 sextracted
# > Line: 3700  Objects:      212 detected /      138 sextracted
# > Line: 3724  Objects:      212 detected /      140 sextracted
# > Line: 3725  Objects:      212 detected /      140 sextracted
# > Line: 3725  Objects:      212 detected /      141 sextracted
# > Line: 3750  Objects:      212 detected /      144 sextracted
# > Line: 3775  Objects:      212 detected /      145 sextracted
# > Line: 3800  Objects:      212 detected /      146 sextracted
# > Line: 3825  Objects:      213 detected /      149 sextracted
# > Line: 3850  Objects:      214 detected /      149 sextracted
# > Line: 3875  Objects:      217 detected /      149 sextracted
# > Line: 3900  Objects:      217 detected /      149 sextracted
# > Line: 3925  Objects:      217 detected /      149 sextracted
# > Line: 3950  Objects:      218 detected /      149 sextracted
# > Line: 3975  Objects:      220 detected /      149 sextracted
# > Line: 4000  Objects:      221 detected /      149 sextracted
# > Line: 4025  Objects:      221 detected /      149 sextracted
# > Line: 4050  Objects:      221 detected /      149 sextracted
# > Line: 4075  Objects:      222 detected /      149 sextracted
# > Line: 4100  Objects:      222 detected /      149 sextracted
# > Line: 4108  Objects:      222 detected /      150 sextracted
# > Line: 4108  Objects:      222 detected /      160 sextracted
# > Line: 4108  Objects:      222 detected /      170 sextracted
# > Line: 4108  Objects:      222 detected /      180 sextracted
# > Line: 4108  Objects:      222 detected /      190 sextracted
# > Line: 4108  Objects:      222 detected /      200 sextracted
# > Line: 4108  Objects:      222 detected /      210 sextracted
# > Line: 4108  Objects:      222 detected /      220 sextracted
#       Objects: detected 222      / sextracted 221
#
# > Closing files
# >
# > All done (in 2.5 s: 1662.2 lines/s , 89.4 detections/s)

# %%
with fits.open(psfcatalogName) as HDU:
    psfsourceTable = Table(HDU[2].data)

print(psfsourceTable.colnames)
print(psfsourceTable)

cleanPSFSources = psfsourceTable[(psfsourceTable['FLAGS']==0) & (psfsourceTable['FLAGS_MODEL']==0)  & (psfsourceTable['FWHM_WORLD'] < 2) & (psfsourceTable['XMODEL_IMAGE']<3500) & (psfsourceTable['XMODEL_IMAGE']>500) &(psfsourceTable['YMODEL_IMAGE']<3500) &(psfsourceTable['YMODEL_IMAGE']>500)]
# Out:
# ['VIGNET', 'X_IMAGE', 'Y_IMAGE', 'XWIN_IMAGE', 'YWIN_IMAGE', 'ERRAWIN_IMAGE', 'ERRBWIN_IMAGE', 'ALPHAWIN_J2000', 'DELTAWIN_J2000', 'FLUX_RADIUS', 'FWHM_WORLD', 'FLUX_AUTO', 'FLUXERR_AUTO', 'SNR_WIN', 'ELONGATION', 'FLUX_MAX', 'MAG_AUTO', 'MAGERR_AUTO', 'FLAGS', 'BACKGROUND', 'CLASS_STAR', 'FLAGS_MODEL', 'NITER_MODEL', 'XMODEL_IMAGE', 'YMODEL_IMAGE', 'FLUX_POINTSOURCE', 'FLUXERR_POINTSOURCE', 'MAG_POINTSOURCE', 'MAGERR_POINTSOURCE', 'FLUXRATIO_POINTSOURCE', 'FLUXRATIOERR_POINTSOURCE']
#           VIGNET           X_IMAGE  ... FLUXRATIOERR_POINTSOURCE
# ------------------------- --------- ... ------------------------
#   -16.929665 .. 22.306328  2417.488 ...                      0.0
#     2.2637634 .. 6.153885  2805.876 ...                      0.0
#  -11.066479 .. -29.247993 2071.0793 ...                      0.0
#  -22.728722 .. -14.198463 1415.7877 ...                      0.0
#   -29.660149 .. 5.9923935 1260.1746 ...                      0.0
#  -17.756145 .. -2.4073105 1260.0012 ...                      0.0
#    -1.2082825 .. 9.906868 1828.6741 ...                      0.0
#   -3.8538055 .. -9.010723 2417.4932 ...                      0.0
#    27.334137 .. 22.048744 1229.0016 ...                      0.0
#   14.407951 .. -6.4341125 2688.4873 ...                      0.0
#                       ...       ... ...                      ...
#    8.364044 .. -17.003418 2829.0085 ...                      0.0
#  -0.31998444 .. 18.305046  681.6299 ...                      0.0
#      16.95922 .. 9.220581 2965.3499 ...                      0.0
#   -11.343643 .. 4.8153305  294.9947 ...                      0.0
#   -5.4634094 .. 7.4479904 254.99849 ...                      0.0
#     11.84964 .. -17.66615 2926.0173 ...                      0.0
#    -16.94394 .. 17.692505 1319.9159 ...                      0.0
#   2.4160004 .. -4.1684647 2424.6853 ...                      0.0
# -7.8391876 .. -13.9818535 1209.9054 ...                      0.0
#    4.0595856 .. 19.030876 1936.0024 ...                      0.0
# Length = 221 rows

# %%
psfsourceCatCoords = SkyCoord(ra=cleanPSFSources['ALPHAWIN_J2000'], dec=cleanPSFSources['DELTAWIN_J2000'], frame='icrs', unit='degree')
ps1CatCoords = SkyCoord(ra=good_cat_stars['RAJ2000'], dec=good_cat_stars['DEJ2000'], frame='icrs', unit='degree')
photoDistThresh = 0.6
idx_psfimage, idx_psfps1, d2d, d3d = ps1CatCoords.search_around_sky(psfsourceCatCoords, photoDistThresh*u.arcsec)

print(f'Found {len(idx_psfimage)} good cross-matches')
# Out:
# Found 80 good cross-matches

# %%
plt.figure(figsize=(8,8))
plt.scatter(good_cat_stars['gmag'][idx_psfps1], cleanPSFSources['MAG_POINTSOURCE'][idx_psfimage], color='C0', s=10)
plt.xlabel('PS1 magnitude', fontsize=15)
plt.ylabel('Instrumental PSF-fit magnitude', fontsize=15)
plt.show()

# %%
psfoffsets = ma.array(good_cat_stars['gmag'][idx_psfps1] - cleanPSFSources['MAG_POINTSOURCE'][idx_psfimage])
zero_psfmean, zero_psfmed, zero_psfstd = sigma_clipped_stats(psfoffsets)
print('PSF Mean ZP: %.2f\nPSF Median ZP: %.2f\nPSF STD ZP: %.2f'%(zero_psfmean, zero_psfmed, zero_psfstd))
# Out:
# PSF Mean ZP: 25.37
# PSF Median ZP: 25.51
# PSF STD ZP: 0.20

# %%
ra = 210.910674637
dec = 54.3116510708

sn2023ixf_coords = SkyCoord(ra=[ra], dec=[dec], frame='icrs', unit='degree')
idx_sn2023ixf, idx_cleanpsf_sn2023ixf, d2d, d3d = psfsourceCatCoords.search_around_sky(sn2023ixf_coords, photoDistThresh*u.arcsec)
print(f'Found the source at index {idx_cleanpsf_sn2023ixf[0]}')
# Out:
# Found the source at index 74

# %%
sn2023ixf_psfinstmag = cleanPSFSources[idx_cleanpsf_sn2023ixf]['MAG_POINTSOURCE'][0]
sn2023ixf_psfinstmagerr = cleanPSFSources[idx_cleanpsf_sn2023ixf]['MAGERR_POINTSOURCE'][0]

sn2023ixf_psfmag = zero_psfmed + sn2023ixf_psfinstmag
sn2023ixf_psfmagerr = np.sqrt(sn2023ixf_psfinstmagerr**2 + zero_psfstd**2)

print(f'PSF-fit magnitude of SN2023ixf is {sn2023ixf_psfmag} +/- {sn2023ixf_psfmagerr}')
# Out:
# PSF-fit magnitude of SN2023ixf is 11.239074282073975 +/- 0.20373579977347678
